# %%
# extension to agent copy 4.ipynb F1-score, pos weight
from typing import Tuple, List
from dataclasses import dataclass
from tqdm import tqdm
from datetime import timedelta
import zipfile
import shutil
import tempfile
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import math
import time
import os
import glob
from torch.utils.data import Subset, DataLoader

# %%
class VoxelDataLoader:
    """Loads and processes NPZ voxel data from a zip file"""

    def __init__(self, zip_path: str):
        # Create a temporary directory
        self.temp_dir = tempfile.mkdtemp()
        print(f"Created temporary directory: {self.temp_dir}")

        # Extract zip file
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(self.temp_dir)
        print(f"Extracted zip file to temporary directory")

        # Find all NPZ files
        all_files = glob.glob(os.path.join(self.temp_dir, "**/*.npz"), recursive=True)
        print(f"Found {len(all_files)} total NPZ files")

        if len(all_files) == 0:
            raise ValueError(f"No NPZ files found in zip file")

        random.shuffle(all_files)  # Shuffle before splitting
        cutoff = int(len(all_files))
        self.npz_files = all_files[:cutoff]
        print(f"Using {len(self.npz_files)}")

    def __del__(self):
        """Cleanup temporary directory when object is destroyed"""
        try:
            shutil.rmtree(self.temp_dir)
            print(f"Cleaned up temporary directory: {self.temp_dir}")
        except:
            print(f"Failed to clean up temporary directory: {self.temp_dir}")

    def load_single_file(self, file_path: str) -> Tuple[torch.Tensor, torch.Tensor]:
        data = np.load(file_path)

        # More robust key checking
        if 'complete' not in data or 'partial' not in data:
            raise ValueError(f"NPZ file {file_path} must contain both 'complete' and 'partial' arrays")

        complete = torch.from_numpy(data['complete']).float()
        partial = torch.from_numpy(data['partial']).float()

        # Verify shapes match
        if complete.shape != partial.shape:
            raise ValueError(f"Shape mismatch in {file_path}: complete {complete.shape} vs partial {partial.shape}")

        return complete, partial

    def get_all_data(self) -> List[Tuple[torch.Tensor, torch.Tensor]]:
        """Load all voxel pairs from all NPZ files"""
        all_data = []
        for file_path in self.npz_files:
            complete, partial = self.load_single_file(file_path)
            all_data.append((complete, partial))
        return all_data

    def get_voxel_grids(self, index: int = 0) -> Tuple[torch.Tensor, torch.Tensor]:
        """Returns complete and partial voxel grids from a specific file"""
        if index >= len(self.npz_files):
            raise IndexError(f"Index {index} out of range. Only {len(self.npz_files)} files available.")
        return self.load_single_file(self.npz_files[index])


class VoxelDataset(torch.utils.data.Dataset):
    """PyTorch Dataset for voxel completion"""

    def __init__(self, zip_path: str, transform=None):
        self.data_loader = VoxelDataLoader(zip_path)
        self.transform = transform

    def __len__(self):
        return len(self.data_loader.npz_files)

    def __getitem__(self, idx):
        complete, partial = self.data_loader.get_voxel_grids(idx)
        # Normalize to [0,1] if not already
        complete = (complete > 0).float()
        partial = (partial > 0).float()
        if self.transform:
            complete, partial = self.transform(complete, partial)
        return complete, partial


# Update data loader creation function
def create_data_loader(zip_path: str, batch_size: int = 1, shuffle: bool = True, num_workers: int = 0):
    """Create a PyTorch DataLoader for training"""
    dataset = VoxelDataset(zip_path)
    return torch.utils.data.DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        num_workers=num_workers,
        # pin_memory=True
    )


def split_dataset(dataset, train_ratio=0.8, val_ratio=0.2, seed=42):
    n = len(dataset)
    indices = list(range(n))
    random.Random(seed).shuffle(indices)

    # from dataset: 80% train 20% test 
    n_trainval = int(n * 0.8)
    n_test = n - n_trainval
    trainval_indices = indices[:n_trainval]
    test_indices = indices[n_trainval:]
    # from training data: 80% train 20% validation
    n_train = int(len(trainval_indices) * 0.8)
    train_indices = trainval_indices[:n_train]
    val_indices = trainval_indices[n_train:]

    return train_indices, val_indices, test_indices

def create_data_loaders(zip_path, batch_size=1, shuffle=True, num_workers=0, seed=42):
    dataset = VoxelDataset(zip_path)
    print(f"Dataset size: {len(dataset)}")
    train_idx, val_idx, test_idx = split_dataset(dataset, seed=seed)
    train_loader = DataLoader(Subset(dataset, train_idx), batch_size=batch_size, shuffle=shuffle, num_workers=num_workers)
    val_loader = DataLoader(Subset(dataset, val_idx), batch_size=batch_size, shuffle=False, num_workers=num_workers)
    test_loader = DataLoader(Subset(dataset, test_idx), batch_size=batch_size, shuffle=False, num_workers=num_workers)

    return train_loader, val_loader, test_loader

# ------------------------------
# Positional encoding (fixed for [B, D, H, W, d_model])
# ------------------------------
class PositionalEncoding3D(nn.Module):
    def __init__(self, d_model: int, max_grid_size: int = 32):
        super().__init__()
        self.d_model = d_model
        self.max_grid_size = max_grid_size
        # stored as (D, H, W, d_model)
        self.pos_embed = nn.Parameter(torch.zeros(max_grid_size, max_grid_size, max_grid_size, d_model))
        nn.init.trunc_normal_(self.pos_embed, std=0.02)

    def forward(self, x):
        # x: [B, D, H, W, d_model]
        B, D, H, W, _ = x.shape
        pos = self.pos_embed[:D, :H, :W, :].unsqueeze(0)  # [1, D, H, W, d_model]
        return x + pos

    def get_encoding(self, D, H, W):
        return self.pos_embed[:D, :H, :W, :]

# ------------------------------
# Local attention (your class, unchanged)
# ------------------------------
class LocalAttention(nn.Module):
    def __init__(self, d_model: int, num_heads: int = 4, window_size: int = 3):
        super().__init__()
        self.d_model = d_model
        self.num_heads = num_heads
        self.head_dim = d_model // num_heads
        self.window_size = window_size
        assert d_model % num_heads == 0
        self.q_proj = nn.Linear(d_model, d_model)
        self.k_proj = nn.Linear(d_model, d_model)
        self.v_proj = nn.Linear(d_model, d_model)
        self.out_proj = nn.Linear(d_model, d_model)
        self.scale = self.head_dim ** -0.5

    def forward(self, target_embedding, neighbor_embeddings, mask):
        """
        Args:
            target_embedding: [B, d_model] - Embedding of the voxel to predict.
            neighbor_embeddings: [B, ws, ws, ws, d_model] - Embeddings of the neighborhood.
            mask: [B, ws, ws, ws] - Boolean mask (True for known, False for unknown).
        """
        B = target_embedding.shape[0]
        ws = self.window_size

        neighbor_flat = neighbor_embeddings.view(B, ws * ws * ws, self.d_model)
        mask_flat = mask.view(B, ws * ws * ws)  # [B, ws^3]

        # Query from target embedding: [B, 1, d_model]
        q = self.q_proj(target_embedding.unsqueeze(1))  # [B, 1, d_model]
        # Keys and values from neighbors: [B, ws^3, d_model]
        k = self.k_proj(neighbor_flat)
        v = self.v_proj(neighbor_flat)

        # Reshape for multi-head attention
        q = q.view(B, 1, self.num_heads, self.head_dim).transpose(1, 2)  # [B, num_heads, 1, head_dim]
        k = k.view(B, ws * ws * ws, self.num_heads, self.head_dim).transpose(1, 2)  # [B, num_heads, ws^3, head_dim]
        v = v.view(B, ws * ws * ws, self.num_heads, self.head_dim).transpose(1, 2)  # [B, num_heads, ws^3, head_dim]

        # Attention scores
        scores = torch.matmul(q, k.transpose(-2, -1)) * self.scale  # [B, num_heads, 1, ws^3]

        # Apply mask (True means allowed)
        mask_expanded = mask_flat.unsqueeze(1).unsqueeze(2).expand(-1, self.num_heads, 1, -1)
        scores = scores.masked_fill(~mask_expanded, float('-inf'))

        attn_weights = F.softmax(scores, dim=-1)
        attn_weights = torch.where(torch.isnan(attn_weights), torch.zeros_like(attn_weights), attn_weights)

        out = torch.matmul(attn_weights, v)  # [B, num_heads, 1, head_dim]
        out = out.transpose(1, 2).contiguous().view(B, 1, self.d_model).squeeze(1)
        return self.out_proj(out)

# ------------------------------
# Voxel transformer layer that uses LocalAttention per voxel
# ------------------------------
class VoxelTransformerLayer3D(nn.Module):
    def __init__(self, d_model: int, num_heads: int = 8, window_size: int = 3, dropout: float = 0.1):
        super().__init__()
        self.d_model = d_model
        self.window_size = window_size
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.attention = LocalAttention(d_model, num_heads, window_size)
        self.ffn = nn.Sequential(
            nn.Linear(d_model, d_model * 4),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_model * 4, d_model),
            nn.Dropout(dropout)
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, neighborhood_fn, mask_fn):
        """
        x: [B, D, H, W, d_model]
        neighborhood_fn: callable(grid, d, h, w, window_size) -> [B, ws, ws, ws, d_model]
        mask_fn: callable(D, H, W, d, h, w, window_size) -> [ws,ws,ws] or [1,ws,ws,ws] or [B,ws,ws,ws]
        """
        B, D, H, W, C = x.shape
        out = torch.zeros_like(x)

        for dd in range(D):
            for hh in range(H):
                for ww in range(W):
                    target = x[:, dd, hh, ww, :]  # [B, d_model]
                    neighbors = neighborhood_fn(x, dd, hh, ww, self.window_size)  # [B, ws, ws, ws, d_model]

                    # === robust mask handling ===
                    mask = mask_fn(D, H, W, dd, hh, ww, self.window_size)
                    # mask can be one of: [ws,ws,ws], [1,ws,ws,ws], [B,ws,ws,ws]
                    if mask.dim() == 3:
                        # [ws,ws,ws] -> [1,ws,ws,ws]
                        mask = mask.unsqueeze(0)
                    if mask.shape[0] == 1 and B > 1:
                        # [1,ws,ws,ws] -> [B,ws,ws,ws]
                        mask = mask.expand(B, -1, -1, -1).contiguous()
                    # now mask is guaranteed to be [B, ws, ws, ws]

                    # attention (per-voxel)
                    tgt_norm = self.norm1(target)
                    attn_out = self.attention(tgt_norm, neighbors, mask)
                    target = target + self.dropout(attn_out)

                    # ffn
                    tgt_norm = self.norm2(target)
                    ffn_out = self.ffn(tgt_norm)
                    target = target + ffn_out

                    out[:, dd, hh, ww, :] = target
        return out

# ------------------------------
# Stack layers
# ------------------------------
class VoxelTransformer3D(nn.Module):
    def __init__(self, num_layers: int, d_model: int, num_heads: int, window_size: int, dropout: float = 0.1):
        super().__init__()
        self.layers = nn.ModuleList([
            VoxelTransformerLayer3D(d_model, num_heads, window_size, dropout)
            for _ in range(num_layers)
        ])

    def forward(self, x, neighborhood_fn, mask_fn):
        """
        x: [B, D, H, W, d_model]
        """
        for layer in self.layers:
            x = layer(x, neighborhood_fn, mask_fn)
        return x

# ------------------------------
# Helper functions for voxel candidate selection
# ------------------------------
def get_voxel_candidates(complete_grid, partial_grid, max_voxels: int = 256):
    """
    Returns a balanced *sample* of candidate voxels to predict.
    
    Args:
        complete_grid: [B, 1, D, H, W]
        partial_grid: [B, 1, D, H, W]
        max_voxels: maximum number of candidate voxels per batch element.
    Returns:
        list of voxel coords: (b, d, h, w, label)
    """
    B, _, D, H, W = complete_grid.shape
    candidates = []

    for b in range(B):
        filled = ((complete_grid[b,0]==1) & (partial_grid[b,0]==0)).nonzero(as_tuple=False)
        empty  = ((complete_grid[b,0]==0) & (partial_grid[b,0]==0)).nonzero(as_tuple=False)

        # balance between filled and empty
        k = max_voxels // 2
        filled_k = min(len(filled), k)
        empty_k  = min(len(empty),  k)

        if filled_k > 0:
            filled_idx = torch.randperm(len(filled))[:filled_k]
            filled = filled[filled_idx]
        else:
            filled = []

        if empty_k > 0:
            empty_idx = torch.randperm(len(empty))[:empty_k]
            empty = empty[empty_idx]
        else:
            empty = []

        for f in filled:
            candidates.append((b, f[0].item(), f[1].item(), f[2].item(), 1))
        for e in empty:
            candidates.append((b, e[0].item(), e[1].item(), e[2].item(), 0))

    return candidates


def compute_density(grid, d, h, w, window_size):
    """Counts filled neighbors around voxel. grid: [D,H,W]"""
    D, H, W = grid.shape
    r = window_size // 2
    d0, d1 = max(0, d-r), min(D, d+r+1)
    h0, h1 = max(0, h-r), min(H, h+r+1)
    w0, w1 = max(0, w-r), min(W, w+r+1)
    patch = grid[d0:d1, h0:h1, w0:w1]
    return float(patch.sum().item())

def sort_voxels(candidates, complete_grid, window_size):
    """Sorts voxel list by density then by distance to origin."""
    sorted_list = []
    for (b,d,h,w,label) in candidates:
        density = compute_density(complete_grid[b,0], d,h,w, window_size)
        dist = d + h + w  # Manhattan distance to origin
        sorted_list.append(((b,d,h,w,label), density, dist))
    sorted_list.sort(key=lambda x: (-x[1], x[2]))  # high density first, then close to origin
    return [item[0] for item in sorted_list]

# ------------------------------
# neighborhood_raw: returns raw patch (channel-first) and known_mask
# ------------------------------
def neighborhood_raw(grid, b, d, h, w, window_size):
    """
    grid: [B, 1, D, H, W] (binary partial grid with 1=known occupied and 0=unknown/empty)
    returns:
        patch: [1, 1, ws, ws, ws]  (channel-first, ready for Conv3d)
        known_mask: [1, ws, ws, ws] (boolean True where neighbor is known)
    """
    # grid: [B, C, D, H, W] where C==1
    _, C, D, H, W = grid.shape
    assert C == 1
    r = window_size // 2
    d0, d1 = max(0, d - r), min(D, d + r + 1)
    h0, h1 = max(0, h - r), min(H, h + r + 1)
    w0, w1 = max(0, w - r), min(W, w + r + 1)

    patch = grid[b:b+1, :, d0:d1, h0:h1, w0:w1]  # [1,1,d_patch,h_patch,w_patch]

    # pads: (W_left,W_right,H_top,H_bottom,D_front,D_back)
    pad_d0 = max(0, r - d)
    pad_h0 = max(0, r - h)
    pad_w0 = max(0, r - w)
    pad_d1 = max(0, (d + r + 1) - D)
    pad_h1 = max(0, (h + r + 1) - H)
    pad_w1 = max(0, (w + r + 1) - W)
    pad = (pad_w0, pad_w1, pad_h0, pad_h1, pad_d0, pad_d1)
    if any(p > 0 for p in pad):
        patch = F.pad(patch, pad)  # pad with zeros

    # patch now [1,1,ws,ws,ws]
    # known mask: True if this position was observed as known in partial grid
    known = (patch[:, 0] == 1).to(torch.bool)  # [1, ws, ws, ws]

    return patch.contiguous(), known.contiguous()

# ------------------------------
# IterativeVoxelModel: projection + positional encoding + small transformer on the patch
# ------------------------------
class IterativeVoxelModel(nn.Module):
    def __init__(self, d_model: int = 64, num_heads: int = 4, num_layers: int = 3,
                 window_size: int = 3, max_grid_size: int = 32, dropout: float = 0.1):
        """
        This model expects per-call patch input:
            neighbors_patch: [B, 1, ws, ws, ws]  (binary observed values or zeros)
            known_mask: [B, ws, ws, ws] (boolean)
        The model:
            - projects neighbors -> d_model via Conv3d(1 -> d_model)
            - permutes to [B, Dp, Hp, Wp, d_model], adds positional encoding
            - runs VoxelTransformer3D on the patch
            - extracts center voxel embedding and returns a scalar logit (per batch)
        """
        super().__init__()
        self.d_model = d_model
        self.window_size = window_size
        self.input_proj = nn.Conv3d(1, d_model, kernel_size=1)  # works on [B,1,ws,ws,ws]
        self.pos_encoding = PositionalEncoding3D(d_model, max_grid_size=max_grid_size)
        # use the same transformer as defined above, but it expects patch in [B, D, H, W, d_model]
        self.transformer = VoxelTransformer3D(num_layers=num_layers, d_model=d_model,
                                              num_heads=num_heads, window_size=window_size,
                                              dropout=dropout)
        # output head: from d_model to one logit
        self.output_head = nn.Linear(d_model, 1)

    def forward(self, neighbors_patch, known_mask):
        """
        neighbors_patch: [B, 1, ws, ws, ws]
        known_mask: [B, ws, ws, ws] boolean - True where neighbor is observed/known
        Returns:
            logits: [B, 1] (logit for center voxel occupancy)
        """
        B = neighbors_patch.shape[0]
        ws = self.window_size
        assert neighbors_patch.shape[2:] == (ws, ws, ws), f"neighbors size mismatch {neighbors_patch.shape}"
        # project
        emb = self.input_proj(neighbors_patch)  # [B, d_model, ws, ws, ws]
        # permute to [B, D, H, W, d_model]
        emb = emb.permute(0, 2, 3, 4, 1).contiguous()
        # add positional encoding
        emb = self.pos_encoding(emb)  # [B, ws, ws, ws, d_model]

        # define patch-local neighborhood_fn and mask_fn used by VoxelTransformerLayer3D
        def neighborhood_fn_patch(grid, dd, hh, ww, window_size):
            # grid: [B, Dp, Hp, Wp, d_model] where Dp=ws
            B2, Dp, Hp, Wp, C = grid.shape
            r = window_size // 2
            d0, d1 = max(0, dd - r), min(Dp, dd + r + 1)
            h0, h1 = max(0, hh - r), min(Hp, hh + r + 1)
            w0, w1 = max(0, ww - r), min(Wp, ww + r + 1)
            patch_local = grid[:, d0:d1, h0:h1, w0:w1, :]  # may be smaller than ws on boundaries
            # pad if necessary to shape [B, ws, ws, ws, d_model]
            pd0 = max(0, r - dd); pd1 = max(0, (dd + r + 1) - Dp)
            ph0 = max(0, r - hh); ph1 = max(0, (hh + r + 1) - Hp)
            pw0 = max(0, r - ww); pw1 = max(0, (ww + r + 1) - Wp)
            if any([pd0,pd1,ph0,ph1,pw0,pw1]):
                # permute to channel-first temporarily to use F.pad on last 3 dims
                # patch_local: [B, d_patch, h_patch, w_patch, C] -> permute to [B, C, d,h,w]
                tmp = patch_local.permute(0, 4, 1, 2, 3).contiguous()
                pad = (pw0, pw1, ph0, ph1, pd0, pd1)
                tmp = F.pad(tmp, pad)
                patch_local = tmp.permute(0, 2, 3, 4, 1).contiguous()
            # ensure final shape is [B, ws, ws, ws, d_model]
            return patch_local

        def mask_fn_patch(Dp, Hp, Wp, dd, hh, ww, window_size):
            # We'll use the known_mask passed to the outer forward to compute mask per patch position
            # known_mask: [B, ws, ws, ws] - but voxel transformer expects mask independent of batch or same across batch
            # We return per-batch masks in VoxelTransformerLayer3D; it will expand as needed.
            # compute boundaries within patch
            r = window_size // 2
            d0, d1 = max(0, dd - r), min(Dp, dd + r + 1)
            h0, h1 = max(0, hh - r), min(Hp, hh + r + 1)
            w0, w1 = max(0, ww - r), min(Wp, ww + r + 1)
            # Because we already have known_mask for the entire patch, we'll extract the appropriate patch of known_mask
            # BUT VoxelTransformerLayer3D will call mask_fn_patch(Dp,Hp,Wp,dd,hh,ww,ws) which doesn't give batch index.
            # To keep simple, return a mask that will be interpreted per-batch inside VoxelTransformerLayer3D.
            # We'll return the mask for a single (arbitrary) batch element shape [ws,ws,ws], but VoxelTransformerLayer3D
            # will expand to [B, ws, ws, ws].
            # Build a mask with all True (attend all) — the LocalAttention will still receive per-batch mask when it is used.
            # Here, deliver a mask that only marks valid (in-range) positions (True) — padding areas will be False.
            mask = torch.ones((window_size, window_size, window_size), dtype=torch.bool, device=emb.device)
            # pad areas relative to patch edges:
            pd0 = max(0, r - dd); pd1 = max(0, (dd + r + 1) - Dp)
            ph0 = max(0, r - hh); ph1 = max(0, (hh + r + 1) - Hp)
            pw0 = max(0, r - ww); pw1 = max(0, (ww + r + 1) - Wp)
            if pd0 > 0:
                mask[:pd0, :, :] = False
            if pd1 > 0:
                mask[-pd1:, :, :] = False
            if ph0 > 0:
                mask[:, :ph0, :] = False
            if ph1 > 0:
                mask[:, -ph1:, :] = False
            if pw0 > 0:
                mask[:, :, :pw0] = False
            if pw1 > 0:
                mask[:, :, -pw1:] = False
            return mask.unsqueeze(0)  # [1, ws, ws, ws]

        # Now run the transformer on emb patch
        # emb: [B, ws, ws, ws, d_model]
        # we must give neighborhood_fn_patch and mask_fn_patch to transformer
        out_patch = self.transformer(emb, neighborhood_fn_patch, mask_fn_patch)  # [B, ws, ws, ws, d_model]

        # extract center voxel index
        center = ws // 2
        center_emb = out_patch[:, center, center, center, :]  # [B, d_model]
        logits = self.output_head(center_emb)  # [B, 1]
        return logits


def neighborhood_fn(grid, b, d, h, w, window_size):
    """
    Extract a cubic neighborhood around voxel (d,h,w) from batch element b.
    grid: [B, C, D, H, W]
    Returns: [1, C, ws, ws, ws]
    """
    assert grid.dim() == 5, f"Expected 5D grid, got {grid.shape}"
    assert window_size % 2 == 1, "window_size must be odd."
    radius = window_size // 2

    # Pad grid symmetrically
    padded = F.pad(grid[b:b+1], (radius, radius, radius, radius, radius, radius), mode="constant", value=0)

    # shift indices because of padding
    d, h, w = d + radius, h + radius, w + radius

    # slice out the patch
    patch = padded[:, :, d-radius:d+radius+1, h-radius:h+radius+1, w-radius:w+radius+1]
    return patch  # [1, C, ws, ws, ws]


def mask_fn(grid_shape, d, h, w, window_size):
    """
    Create a binary mask for the cubic neighborhood around (d,h,w).
    grid_shape: (D,H,W)
    Returns: [1, ws, ws, ws]
    """
    D, H, W = grid_shape
    assert window_size % 2 == 1, "window_size must be odd."
    radius = window_size // 2

    mask = torch.ones((window_size, window_size, window_size), dtype=torch.float32)

    # Prevent model from "seeing" the target voxel itself
    mask[radius, radius, radius] = 0.0

    # Handle boundaries (mask out-of-range neighbors)
    for dd in range(window_size):
        for hh in range(window_size):
            for ww in range(window_size):
                gd, gh, gw = d + dd - radius, h + hh - radius, w + ww - radius
                if not (0 <= gd < D and 0 <= gh < H and 0 <= gw < W):
                    mask[dd, hh, ww] = 0.0

    return mask.unsqueeze(0)  # [1, ws, ws, ws]

# %%
MODEL_SAVE_PATH = "iterative_model.pth"

# %%
import numpy as np
import torch
import glob
import json 

# zip_path = "../../model_data/chunk_data_16_flood_fill_rm_20.zip"
zip_path = "/home/raedfidawi/Documents/thesis/3DLLM/chunk_data_16_flood_fill_rm_20.zip"
dataset = VoxelDataset(zip_path)

test_dir = "../../test_data/test_data_rm_20_RES_32/"
test_indices_file = os.path.join(test_dir, "test_indices.json")

with open(test_indices_file, "r") as f:
    test_idx = json.load(f)

test_samples = []
for idx in range(1000):
    complete, partial = dataset[idx]
    test_samples.append((complete, partial))

print(f"Loaded {len(test_samples)} test samples from {test_dir}")
# Out:
# Created temporary directory: /tmp/tmpn8lpdtnz
# Extracted zip file to temporary directory
# Found 256571 total NPZ files
# Using 256571
# Loaded 1000 test samples from ../../test_data/test_data_rm_20_RES_32/

# %% [markdown]
# # Voxels given to Model: All empty voxels

# %%
import torch
import numpy as np
import random
from collections import deque

def iterative_inference(model_path, test_samples, device):
    """
    Perform iterative inference on a random partial voxel object from test_samples.
    Sorts empty voxels by density in 3x3x3 window (filled neighbors), breaking ties by distance to origin.
    """
    print(f"Using device: {device}")
    # Pick a random sample
    # sample_idx = random.randint(0, len(test_samples)-1)
    sample_idx = 641
    complete, partial = test_samples[sample_idx]

    print(f"Selected sample index: {sample_idx}")
    
    # Load model
    # model = IterativeVoxelModel(
    #     d_model=96,
    #     num_heads=6,
    #     num_layers=3,
    #     max_grid_size=32,
    #     window_size=3,
    #     dropout=0.1
    # ).to(device)

    model = IterativeVoxelModel(
        d_model=48,
        num_heads=4,
        num_layers=3,
        max_grid_size=16,
        window_size=5,
        dropout=0.1
    ).to(device)

    # Load checkpoint
    checkpoint = torch.load(model_path, map_location=device)
    state_dict = checkpoint['model_state_dict']

    # Handle DataParallel prefix
    from collections import OrderedDict
    new_state_dict = OrderedDict()
    for k, v in state_dict.items():
        new_key = k.replace('module.', '') if k.startswith('module.') else k
        new_state_dict[new_key] = v
    model.load_state_dict(new_state_dict)
    model.eval()

    partial_tensor = partial.unsqueeze(0).unsqueeze(0).to(device)  # [1,1,D,H,W]
    known_mask = (partial_tensor > 0).float()  # initially known voxels

    D, H, W = partial.shape
    window = model.window_size
    half = window // 2

    # Get coordinates of empty voxels as (x,y,z)
    empty_voxels = torch.nonzero(partial_tensor[0,0] == 0, as_tuple=False)  # [N,3]

    # --- Sort empty voxels by density in 3x3x3 window, break ties by distance to origin ---
    def count_filled_neighbors_3x3x3(x, y, z, grid):
        count = 0
        for dx in [-1, 0, 1]:
            for dy in [-1, 0, 1]:
                for dz in [-1, 0, 1]:
                    nx, ny, nz = x + dx, y + dy, z + dz
                    if 0 <= nx < D and 0 <= ny < H and 0 <= nz < W:
                        if dx == 0 and dy == 0 and dz == 0:
                            continue
                        if grid[0,0,nx,ny,nz] > 0:
                            count += 1
        return count

    voxel_scores = []
    for v in empty_voxels:
        x, y, z = v.tolist()
        density = count_filled_neighbors_3x3x3(x, y, z, partial_tensor)
        dist = x**2 + y**2 + z**2  # Euclidean squared distance to origin
        voxel_scores.append((x, y, z, density, dist))

    # Sort: high density first, then close to origin
    voxel_scores.sort(key=lambda x: (-x[3], x[4]))
    sorted_empty_voxels = [(x, y, z) for x, y, z, _, _ in voxel_scores]
    print("Entering prediction...")
    with torch.no_grad():
        i = 0
        for x, y, z in sorted_empty_voxels:
            patch, mask_patch = neighborhood_raw(partial_tensor, 0, x, y, z, window)
            logits = model(patch.to(device), mask_patch.to(device))  # [1,1]
            prob = torch.sigmoid(logits).squeeze().item()
            pred_filled = 1.0 if prob > 0.9 else 0.0
            partial_tensor[0,0,x,y,z] = pred_filled
            known_mask[0,0,x,y,z] = 1.0
            print(f"Predicted {i}th Voxel")
            i += 1

    # Save outputs
    output_voxels = partial_tensor.squeeze().cpu().numpy()
    np.save("output_voxel.npy", output_voxels)
    np.save("partial_voxel.npy", partial.numpy())
    np.save("complete_voxel.npy", complete.numpy())

    print("Inference complete. Voxels saved to output_voxel.npy, partial_voxel.npy, complete_voxel.npy.")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
iterative_inference(MODEL_SAVE_PATH, test_samples, device=device)
# Out:
# Using device: cuda
# Selected sample index: 641
# Entering prediction...
# Predicted 0th Voxel
# Predicted 1th Voxel
# Predicted 2th Voxel
# Predicted 3th Voxel
# Predicted 4th Voxel
# Predicted 5th Voxel
# Predicted 6th Voxel
# Predicted 7th Voxel
# Predicted 8th Voxel
# Predicted 9th Voxel
# Predicted 10th Voxel
# Predicted 11th Voxel
# Predicted 12th Voxel
# Predicted 13th Voxel
# Predicted 14th Voxel
# Predicted 15th Voxel
# Predicted 16th Voxel
# Predicted 17th Voxel
# Predicted 18th Voxel
# Predicted 19th Voxel
# Predicted 20th Voxel
# Predicted 21th Voxel
# Predicted 22th Voxel
# Predicted 23th Voxel
# Predicted 24th Voxel
# Predicted 25th Voxel
# Predicted 26th Voxel
# Predicted 27th Voxel
# Predicted 28th Voxel
# Predicted 29th Voxel
# Predicted 30th Voxel
# Predicted 31th Voxel
# Predicted 32th Voxel
# Predicted 33th Voxel
# Predicted 34th Voxel
# Predicted 35th Voxel
# Predicted 36th Voxel
# Predicted 37th Voxel
# Predicted 38th Voxel
# Predicted 39th Voxel
# Predicted 40th Voxel
# Predicted 41th Voxel
# Predicted 42th Voxel
# Predicted 43th Voxel
# Predicted 44th Voxel
# Predicted 45th Voxel
# Predicted 46th Voxel
# Predicted 47th Voxel
# Predicted 48th Voxel
# Predicted 49th Voxel
# Predicted 50th Voxel
# Predicted 51th Voxel
# Predicted 52th Voxel
# Predicted 53th Voxel
# Predicted 54th Voxel
# Predicted 55th Voxel
# Predicted 56th Voxel
# Predicted 57th Voxel
# Predicted 58th Voxel
# Predicted 59th Voxel
# Predicted 60th Voxel
# Predicted 61th Voxel
# Predicted 62th Voxel
# Predicted 63th Voxel
# Predicted 64th Voxel
# Predicted 65th Voxel
# Predicted 66th Voxel
# Predicted 67th Voxel
# Predicted 68th Voxel
# Predicted 69th Voxel
# Predicted 70th Voxel
# Predicted 71th Voxel
# Predicted 72th Voxel
# Predicted 73th Voxel
# Predicted 74th Voxel
# Predicted 75th Voxel
# Predicted 76th Voxel
# Predicted 77th Voxel
# Predicted 78th Voxel
# Predicted 79th Voxel
# Predicted 80th Voxel
# Predicted 81th Voxel
# Predicted 82th Voxel
# Predicted 83th Voxel
# Predicted 84th Voxel
# Predicted 85th Voxel
# Predicted 86th Voxel
# Predicted 87th Voxel
# Predicted 88th Voxel
# Predicted 89th Voxel
# Predicted 90th Voxel
# Predicted 91th Voxel
# Predicted 92th Voxel
# Predicted 93th Voxel
# Predicted 94th Voxel
# Predicted 95th Voxel
# Predicted 96th Voxel
# Predicted 97th Voxel
# Predicted 98th Voxel
# Predicted 99th Voxel
# Predicted 100th Voxel
# Predicted 101th Voxel
# Predicted 102th Voxel
# Predicted 103th Voxel
# Predicted 104th Voxel
# Predicted 105th Voxel
# Predicted 106th Voxel
# Predicted 107th Voxel
# Predicted 108th Voxel
# Predicted 109th Voxel
# Predicted 110th Voxel
# Predicted 111th Voxel
# Predicted 112th Voxel
# Predicted 113th Voxel
# Predicted 114th Voxel
# Predicted 115th Voxel
# Predicted 116th Voxel
# Predicted 117th Voxel
# Predicted 118th Voxel
# Predicted 119th Voxel
# Predicted 120th Voxel
# Predicted 121th Voxel
# Predicted 122th Voxel
# Predicted 123th Voxel
# Predicted 124th Voxel
# Predicted 125th Voxel
# Predicted 126th Voxel
# Predicted 127th Voxel
# Predicted 128th Voxel
# Predicted 129th Voxel
# Predicted 130th Voxel
# Predicted 131th Voxel
# Predicted 132th Voxel
# Predicted 133th Voxel
# Predicted 134th Voxel
# Predicted 135th Voxel
# Predicted 136th Voxel
# Predicted 137th Voxel
# Predicted 138th Voxel
# Predicted 139th Voxel
# Predicted 140th Voxel
# Predicted 141th Voxel
# Predicted 142th Voxel
# Predicted 143th Voxel
# Predicted 144th Voxel
# Predicted 145th Voxel
# Predicted 146th Voxel
# Predicted 147th Voxel
# Predicted 148th Voxel
# Predicted 149th Voxel
# Predicted 150th Voxel
# Predicted 151th Voxel
# Predicted 152th Voxel
# Predicted 153th Voxel
# Predicted 154th Voxel
# Predicted 155th Voxel
# Predicted 156th Voxel
# Predicted 157th Voxel
# Predicted 158th Voxel
# Predicted 159th Voxel
# Predicted 160th Voxel
# Predicted 161th Voxel
# Predicted 162th Voxel
# Predicted 163th Voxel
# Predicted 164th Voxel
# Predicted 165th Voxel
# Predicted 166th Voxel
# Predicted 167th Voxel
# Predicted 168th Voxel
# Predicted 169th Voxel
# Predicted 170th Voxel
# Predicted 171th Voxel
# Predicted 172th Voxel
# Predicted 173th Voxel
# Predicted 174th Voxel
# Predicted 175th Voxel
# Predicted 176th Voxel
# Predicted 177th Voxel
# Predicted 178th Voxel
# Predicted 179th Voxel
# Predicted 180th Voxel
# Predicted 181th Voxel
# Predicted 182th Voxel
# Predicted 183th Voxel
# Predicted 184th Voxel
# Predicted 185th Voxel
# Predicted 186th Voxel
# Predicted 187th Voxel
# Predicted 188th Voxel
# Predicted 189th Voxel
# Predicted 190th Voxel
# Predicted 191th Voxel
# Predicted 192th Voxel
# Predicted 193th Voxel
# Predicted 194th Voxel
# Predicted 195th Voxel
# Predicted 196th Voxel
# Predicted 197th Voxel
# Predicted 198th Voxel
# Predicted 199th Voxel
# Predicted 200th Voxel
# Predicted 201th Voxel
# Predicted 202th Voxel
# Predicted 203th Voxel
# Predicted 204th Voxel
# Predicted 205th Voxel
# Predicted 206th Voxel
# Predicted 207th Voxel
# Predicted 208th Voxel
# Predicted 209th Voxel
# Predicted 210th Voxel
# Predicted 211th Voxel
# Predicted 212th Voxel
# Predicted 213th Voxel
# Predicted 214th Voxel
# Predicted 215th Voxel
# Predicted 216th Voxel
# Predicted 217th Voxel
# Predicted 218th Voxel
# Predicted 219th Voxel
# Predicted 220th Voxel
# Predicted 221th Voxel
# Predicted 222th Voxel
# Predicted 223th Voxel
# Predicted 224th Voxel
# Predicted 225th Voxel
# Predicted 226th Voxel
# Predicted 227th Voxel
# Predicted 228th Voxel
# Predicted 229th Voxel
# Predicted 230th Voxel
# Predicted 231th Voxel
# Predicted 232th Voxel
# Predicted 233th Voxel
# Predicted 234th Voxel
# Predicted 235th Voxel
# Predicted 236th Voxel
# Predicted 237th Voxel
# Predicted 238th Voxel
# Predicted 239th Voxel
# Predicted 240th Voxel
# Predicted 241th Voxel
# Predicted 242th Voxel
# Predicted 243th Voxel
# Predicted 244th Voxel
# Predicted 245th Voxel
# Predicted 246th Voxel
# Predicted 247th Voxel
# Predicted 248th Voxel
# Predicted 249th Voxel
# Predicted 250th Voxel
# Predicted 251th Voxel
# Predicted 252th Voxel
# Predicted 253th Voxel
# Predicted 254th Voxel
# Predicted 255th Voxel
# Predicted 256th Voxel
# Predicted 257th Voxel
# Predicted 258th Voxel
# Predicted 259th Voxel
# Predicted 260th Voxel
# Predicted 261th Voxel
# Predicted 262th Voxel
# Predicted 263th Voxel
# Predicted 264th Voxel
# Predicted 265th Voxel
# Predicted 266th Voxel
# Predicted 267th Voxel
# Predicted 268th Voxel
# Predicted 269th Voxel
# Predicted 270th Voxel
# Predicted 271th Voxel
# Predicted 272th Voxel
# Predicted 273th Voxel
# Predicted 274th Voxel
# Predicted 275th Voxel
# Predicted 276th Voxel
# Predicted 277th Voxel
# Predicted 278th Voxel
# Predicted 279th Voxel
# Predicted 280th Voxel
# Predicted 281th Voxel
# Predicted 282th Voxel
# Predicted 283th Voxel
# Predicted 284th Voxel
# Predicted 285th Voxel
# Predicted 286th Voxel
# Predicted 287th Voxel
# Predicted 288th Voxel
# Predicted 289th Voxel
# Predicted 290th Voxel
# Predicted 291th Voxel
# Predicted 292th Voxel
# Predicted 293th Voxel
# Predicted 294th Voxel
# Predicted 295th Voxel
# Predicted 296th Voxel
# Predicted 297th Voxel
# Predicted 298th Voxel
# Predicted 299th Voxel
# Predicted 300th Voxel
# Predicted 301th Voxel
# Predicted 302th Voxel
# Predicted 303th Voxel
# Predicted 304th Voxel
# Predicted 305th Voxel
# Predicted 306th Voxel
# Predicted 307th Voxel
# Predicted 308th Voxel
# Predicted 309th Voxel
# Predicted 310th Voxel
# Predicted 311th Voxel
# Predicted 312th Voxel
# Predicted 313th Voxel
# Predicted 314th Voxel
# Predicted 315th Voxel
# Predicted 316th Voxel
# Predicted 317th Voxel
# Predicted 318th Voxel
# Predicted 319th Voxel
# Predicted 320th Voxel
# Predicted 321th Voxel
# Predicted 322th Voxel
# Predicted 323th Voxel
# Predicted 324th Voxel
# Predicted 325th Voxel
# Predicted 326th Voxel
# Predicted 327th Voxel
# Predicted 328th Voxel
# Predicted 329th Voxel
# Predicted 330th Voxel
# Predicted 331th Voxel
# Predicted 332th Voxel
# Predicted 333th Voxel
# Predicted 334th Voxel
# Predicted 335th Voxel
# Predicted 336th Voxel
# Predicted 337th Voxel
# Predicted 338th Voxel
# Predicted 339th Voxel
# Predicted 340th Voxel
# Predicted 341th Voxel
# Predicted 342th Voxel
# Predicted 343th Voxel
# Predicted 344th Voxel
# Predicted 345th Voxel
# Predicted 346th Voxel
# Predicted 347th Voxel
# Predicted 348th Voxel
# Predicted 349th Voxel
# Predicted 350th Voxel
# Predicted 351th Voxel
# Predicted 352th Voxel
# Predicted 353th Voxel
# Predicted 354th Voxel
# Predicted 355th Voxel
# Predicted 356th Voxel
# Predicted 357th Voxel
# Predicted 358th Voxel
# Predicted 359th Voxel
# Predicted 360th Voxel
# Predicted 361th Voxel
# Predicted 362th Voxel
# Predicted 363th Voxel
# Predicted 364th Voxel
# Predicted 365th Voxel
# Predicted 366th Voxel
# Predicted 367th Voxel
# Predicted 368th Voxel
# Predicted 369th Voxel
# Predicted 370th Voxel
# Predicted 371th Voxel
# Predicted 372th Voxel
# Predicted 373th Voxel
# Predicted 374th Voxel
# Predicted 375th Voxel
# Predicted 376th Voxel
# Predicted 377th Voxel
# Predicted 378th Voxel
# Predicted 379th Voxel
# Predicted 380th Voxel
# Predicted 381th Voxel
# Predicted 382th Voxel
# Predicted 383th Voxel
# Predicted 384th Voxel
# Predicted 385th Voxel
# Predicted 386th Voxel
# Predicted 387th Voxel
# Predicted 388th Voxel
# Predicted 389th Voxel
# Predicted 390th Voxel
# Predicted 391th Voxel
# Predicted 392th Voxel
# Predicted 393th Voxel
# Predicted 394th Voxel
# Predicted 395th Voxel
# Predicted 396th Voxel
# Predicted 397th Voxel
# Predicted 398th Voxel
# Predicted 399th Voxel
# Predicted 400th Voxel
# Predicted 401th Voxel
# Predicted 402th Voxel
# Predicted 403th Voxel
# Predicted 404th Voxel
# Predicted 405th Voxel
# Predicted 406th Voxel
# Predicted 407th Voxel
# Predicted 408th Voxel
# Predicted 409th Voxel
# Predicted 410th Voxel
# Predicted 411th Voxel
# Predicted 412th Voxel
# Predicted 413th Voxel
# Predicted 414th Voxel
# Predicted 415th Voxel
# Predicted 416th Voxel
# Predicted 417th Voxel
# Predicted 418th Voxel
# Predicted 419th Voxel
# Predicted 420th Voxel
# Predicted 421th Voxel
# Predicted 422th Voxel
# Predicted 423th Voxel
# Predicted 424th Voxel
# Predicted 425th Voxel
# Predicted 426th Voxel
# Predicted 427th Voxel
# Predicted 428th Voxel
# Predicted 429th Voxel
# Predicted 430th Voxel
# Predicted 431th Voxel
# Predicted 432th Voxel
# Predicted 433th Voxel
# Predicted 434th Voxel
# Predicted 435th Voxel
# Predicted 436th Voxel
# Predicted 437th Voxel
# Predicted 438th Voxel
# Predicted 439th Voxel
# Predicted 440th Voxel
# Predicted 441th Voxel
# Predicted 442th Voxel
# Predicted 443th Voxel
# Predicted 444th Voxel
# Predicted 445th Voxel
# Predicted 446th Voxel
# Predicted 447th Voxel
# Predicted 448th Voxel
# Predicted 449th Voxel
# Predicted 450th Voxel
# Predicted 451th Voxel
# Predicted 452th Voxel
# Predicted 453th Voxel
# Predicted 454th Voxel
# Predicted 455th Voxel
# Predicted 456th Voxel
# Predicted 457th Voxel
# Predicted 458th Voxel
# Predicted 459th Voxel
# Predicted 460th Voxel
# Predicted 461th Voxel
# Predicted 462th Voxel
# Predicted 463th Voxel
# Predicted 464th Voxel
# Predicted 465th Voxel
# Predicted 466th Voxel
# Predicted 467th Voxel
# Predicted 468th Voxel
# Predicted 469th Voxel
# Predicted 470th Voxel
# Predicted 471th Voxel
# Predicted 472th Voxel
# Predicted 473th Voxel
# Predicted 474th Voxel
# Predicted 475th Voxel
# Predicted 476th Voxel
# Predicted 477th Voxel
# Predicted 478th Voxel
# Predicted 479th Voxel
# Predicted 480th Voxel
# Predicted 481th Voxel
# Predicted 482th Voxel
# Predicted 483th Voxel
# Predicted 484th Voxel
# Predicted 485th Voxel
# Predicted 486th Voxel
# Predicted 487th Voxel
# Predicted 488th Voxel
# Predicted 489th Voxel
# Predicted 490th Voxel
# Predicted 491th Voxel
# Predicted 492th Voxel
# Predicted 493th Voxel
# Predicted 494th Voxel
# Predicted 495th Voxel
# Predicted 496th Voxel
# Predicted 497th Voxel
# Predicted 498th Voxel
# Predicted 499th Voxel
# Predicted 500th Voxel
# Predicted 501th Voxel
# Predicted 502th Voxel
# Predicted 503th Voxel
# Predicted 504th Voxel
# Predicted 505th Voxel
# Predicted 506th Voxel
# Predicted 507th Voxel
# Predicted 508th Voxel
# Predicted 509th Voxel
# Predicted 510th Voxel
# Predicted 511th Voxel
# Predicted 512th Voxel
# Predicted 513th Voxel
# Predicted 514th Voxel
# Predicted 515th Voxel
# Predicted 516th Voxel
# Predicted 517th Voxel
# Predicted 518th Voxel
# Predicted 519th Voxel
# Predicted 520th Voxel
# Predicted 521th Voxel
# Predicted 522th Voxel
# Predicted 523th Voxel
# Predicted 524th Voxel
# Predicted 525th Voxel
# Predicted 526th Voxel
# Predicted 527th Voxel
# Predicted 528th Voxel
# Predicted 529th Voxel
# Predicted 530th Voxel
# Predicted 531th Voxel
# Predicted 532th Voxel
# Predicted 533th Voxel
# Predicted 534th Voxel
# Predicted 535th Voxel
# Predicted 536th Voxel
# Predicted 537th Voxel
# Predicted 538th Voxel
# Predicted 539th Voxel
# Predicted 540th Voxel
# Predicted 541th Voxel
# Predicted 542th Voxel
# Predicted 543th Voxel
# Predicted 544th Voxel
# Predicted 545th Voxel
# Predicted 546th Voxel
# Predicted 547th Voxel
# Predicted 548th Voxel
# Predicted 549th Voxel
# Predicted 550th Voxel
# Predicted 551th Voxel
# Predicted 552th Voxel
# Predicted 553th Voxel
# Predicted 554th Voxel
# Predicted 555th Voxel
# Predicted 556th Voxel
# Predicted 557th Voxel
# Predicted 558th Voxel
# Predicted 559th Voxel
# Predicted 560th Voxel
# Predicted 561th Voxel
# Predicted 562th Voxel
# Predicted 563th Voxel
# Predicted 564th Voxel
# Predicted 565th Voxel
# Predicted 566th Voxel
# Predicted 567th Voxel
# Predicted 568th Voxel
# Predicted 569th Voxel
# Predicted 570th Voxel
# Predicted 571th Voxel
# Predicted 572th Voxel
# Predicted 573th Voxel
# Predicted 574th Voxel
# Predicted 575th Voxel
# Predicted 576th Voxel
# Predicted 577th Voxel
# Predicted 578th Voxel
# Predicted 579th Voxel
# Predicted 580th Voxel
# Predicted 581th Voxel
# Predicted 582th Voxel
# Predicted 583th Voxel
# Predicted 584th Voxel
# Predicted 585th Voxel
# Predicted 586th Voxel
# Predicted 587th Voxel
# Predicted 588th Voxel
# Predicted 589th Voxel
# Predicted 590th Voxel
# Predicted 591th Voxel
# Predicted 592th Voxel
# Predicted 593th Voxel
# Predicted 594th Voxel
# Predicted 595th Voxel
# Predicted 596th Voxel
# Predicted 597th Voxel
# Predicted 598th Voxel
# Predicted 599th Voxel
# Predicted 600th Voxel
# Predicted 601th Voxel
# Predicted 602th Voxel
# Predicted 603th Voxel
# Predicted 604th Voxel
# Predicted 605th Voxel
# Predicted 606th Voxel
# Predicted 607th Voxel
# Predicted 608th Voxel
# Predicted 609th Voxel
# Predicted 610th Voxel
# Predicted 611th Voxel
# Predicted 612th Voxel
# Predicted 613th Voxel
# Predicted 614th Voxel
# Predicted 615th Voxel
# Predicted 616th Voxel
# Predicted 617th Voxel
# Predicted 618th Voxel
# Predicted 619th Voxel
# Predicted 620th Voxel
# Predicted 621th Voxel
# Predicted 622th Voxel
# Predicted 623th Voxel
# Predicted 624th Voxel
# Predicted 625th Voxel
# Predicted 626th Voxel
# Predicted 627th Voxel
# Predicted 628th Voxel
# Predicted 629th Voxel
# Predicted 630th Voxel
# Predicted 631th Voxel
# Predicted 632th Voxel
# Predicted 633th Voxel
# Predicted 634th Voxel
# Predicted 635th Voxel
# Predicted 636th Voxel
# Predicted 637th Voxel
# Predicted 638th Voxel
# Predicted 639th Voxel
# Predicted 640th Voxel
# Predicted 641th Voxel
# Predicted 642th Voxel
# Predicted 643th Voxel
# Predicted 644th Voxel
# Predicted 645th Voxel
# Predicted 646th Voxel
# Predicted 647th Voxel
# Predicted 648th Voxel
# Predicted 649th Voxel
# Predicted 650th Voxel
# Predicted 651th Voxel
# Predicted 652th Voxel
# Predicted 653th Voxel
# Predicted 654th Voxel
# Predicted 655th Voxel
# Predicted 656th Voxel
# Predicted 657th Voxel
# Predicted 658th Voxel
# Predicted 659th Voxel
# Predicted 660th Voxel
# Predicted 661th Voxel
# Predicted 662th Voxel
# Predicted 663th Voxel
# Predicted 664th Voxel
# Predicted 665th Voxel
# Predicted 666th Voxel
# Predicted 667th Voxel
# Predicted 668th Voxel
# Predicted 669th Voxel
# Predicted 670th Voxel
# Predicted 671th Voxel
# Predicted 672th Voxel
# Predicted 673th Voxel
# Predicted 674th Voxel
# Predicted 675th Voxel
# Predicted 676th Voxel
# Predicted 677th Voxel
# Predicted 678th Voxel
# Predicted 679th Voxel
# Predicted 680th Voxel
# Predicted 681th Voxel
# Predicted 682th Voxel
# Predicted 683th Voxel
# Predicted 684th Voxel
# Predicted 685th Voxel
# Predicted 686th Voxel
# Predicted 687th Voxel
# Predicted 688th Voxel
# Predicted 689th Voxel
# Predicted 690th Voxel
# Predicted 691th Voxel
# Predicted 692th Voxel
# Predicted 693th Voxel
# Predicted 694th Voxel
# Predicted 695th Voxel
# Predicted 696th Voxel
# Predicted 697th Voxel
# Predicted 698th Voxel
# Predicted 699th Voxel
# Predicted 700th Voxel
# Predicted 701th Voxel
# Predicted 702th Voxel
# Predicted 703th Voxel
# Predicted 704th Voxel
# Predicted 705th Voxel
# Predicted 706th Voxel
# Predicted 707th Voxel
# Predicted 708th Voxel
# Predicted 709th Voxel
# Predicted 710th Voxel
# Predicted 711th Voxel
# Predicted 712th Voxel
# Predicted 713th Voxel
# Predicted 714th Voxel
# Predicted 715th Voxel
# Predicted 716th Voxel
# Predicted 717th Voxel
# Predicted 718th Voxel
# Predicted 719th Voxel
# Predicted 720th Voxel
# Predicted 721th Voxel
# Predicted 722th Voxel
# Predicted 723th Voxel
# Predicted 724th Voxel
# Predicted 725th Voxel
# Predicted 726th Voxel
# Predicted 727th Voxel
# Predicted 728th Voxel
# Predicted 729th Voxel
# Predicted 730th Voxel
# Predicted 731th Voxel
# Predicted 732th Voxel
# Predicted 733th Voxel
# Predicted 734th Voxel
# Predicted 735th Voxel
# Predicted 736th Voxel
# Predicted 737th Voxel
# Predicted 738th Voxel
# Predicted 739th Voxel
# Predicted 740th Voxel
# Predicted 741th Voxel
# Predicted 742th Voxel
# Predicted 743th Voxel
# Predicted 744th Voxel
# Predicted 745th Voxel
# Predicted 746th Voxel
# Predicted 747th Voxel
# Predicted 748th Voxel
# Predicted 749th Voxel
# Predicted 750th Voxel
# Predicted 751th Voxel
# Predicted 752th Voxel
# Predicted 753th Voxel
# Predicted 754th Voxel
# Predicted 755th Voxel
# Predicted 756th Voxel
# Predicted 757th Voxel
# Predicted 758th Voxel
# Predicted 759th Voxel
# Predicted 760th Voxel
# Predicted 761th Voxel
# Predicted 762th Voxel
# Predicted 763th Voxel
# Predicted 764th Voxel
# Predicted 765th Voxel
# Predicted 766th Voxel
# Predicted 767th Voxel
# Predicted 768th Voxel
# Predicted 769th Voxel
# Predicted 770th Voxel
# Predicted 771th Voxel
# Predicted 772th Voxel
# Predicted 773th Voxel
# Predicted 774th Voxel
# Predicted 775th Voxel
# Predicted 776th Voxel
# Predicted 777th Voxel
# Predicted 778th Voxel
# Predicted 779th Voxel
# Predicted 780th Voxel
# Predicted 781th Voxel
# Predicted 782th Voxel
# Predicted 783th Voxel
# Predicted 784th Voxel
# Predicted 785th Voxel
# Predicted 786th Voxel
# Predicted 787th Voxel
# Predicted 788th Voxel
# Predicted 789th Voxel
# Predicted 790th Voxel
# Predicted 791th Voxel
# Predicted 792th Voxel
# Predicted 793th Voxel
# Predicted 794th Voxel
# Predicted 795th Voxel
# Predicted 796th Voxel
# Predicted 797th Voxel
# Predicted 798th Voxel
# Predicted 799th Voxel
# Predicted 800th Voxel
# Predicted 801th Voxel
# Predicted 802th Voxel
# Predicted 803th Voxel
# Predicted 804th Voxel
# Predicted 805th Voxel
# Predicted 806th Voxel
# Predicted 807th Voxel
# Predicted 808th Voxel
# Predicted 809th Voxel
# Predicted 810th Voxel
# Predicted 811th Voxel
# Predicted 812th Voxel
# Predicted 813th Voxel
# Predicted 814th Voxel
# Predicted 815th Voxel
# Predicted 816th Voxel
# Predicted 817th Voxel
# Predicted 818th Voxel
# Predicted 819th Voxel
# Predicted 820th Voxel
# Predicted 821th Voxel
# Predicted 822th Voxel
# Predicted 823th Voxel
# Predicted 824th Voxel
# Predicted 825th Voxel
# Predicted 826th Voxel
# Predicted 827th Voxel
# Predicted 828th Voxel
# Predicted 829th Voxel
# Predicted 830th Voxel
# Predicted 831th Voxel
# Predicted 832th Voxel
# Predicted 833th Voxel
# Predicted 834th Voxel
# Predicted 835th Voxel
# Predicted 836th Voxel
# Predicted 837th Voxel
# Predicted 838th Voxel
# Predicted 839th Voxel
# Predicted 840th Voxel
# Predicted 841th Voxel
# Predicted 842th Voxel
# Predicted 843th Voxel
# Predicted 844th Voxel
# Predicted 845th Voxel
# Predicted 846th Voxel
# Predicted 847th Voxel
# Predicted 848th Voxel
# Predicted 849th Voxel
# Predicted 850th Voxel
# Predicted 851th Voxel
# Predicted 852th Voxel
# Predicted 853th Voxel
# Predicted 854th Voxel
# Predicted 855th Voxel
# Predicted 856th Voxel
# Predicted 857th Voxel
# Predicted 858th Voxel
# Predicted 859th Voxel
# Predicted 860th Voxel
# Predicted 861th Voxel
# Predicted 862th Voxel
# Predicted 863th Voxel
# Predicted 864th Voxel
# Predicted 865th Voxel
# Predicted 866th Voxel
# Predicted 867th Voxel
# Predicted 868th Voxel
# Predicted 869th Voxel
# Predicted 870th Voxel
# Predicted 871th Voxel
# Predicted 872th Voxel
# Predicted 873th Voxel
# Predicted 874th Voxel
# Predicted 875th Voxel
# Predicted 876th Voxel
# Predicted 877th Voxel
# Predicted 878th Voxel
# Predicted 879th Voxel
# Predicted 880th Voxel
# Predicted 881th Voxel
# Predicted 882th Voxel
# Predicted 883th Voxel
# Predicted 884th Voxel
# Predicted 885th Voxel
# Predicted 886th Voxel
# Predicted 887th Voxel
# Predicted 888th Voxel
# Predicted 889th Voxel
# Predicted 890th Voxel
# Predicted 891th Voxel
# Predicted 892th Voxel
# Predicted 893th Voxel
# Predicted 894th Voxel
# Predicted 895th Voxel
# Predicted 896th Voxel
# Predicted 897th Voxel
# Predicted 898th Voxel
# Predicted 899th Voxel
# Predicted 900th Voxel
# Predicted 901th Voxel
# Predicted 902th Voxel
# Predicted 903th Voxel
# Predicted 904th Voxel
# Predicted 905th Voxel
# Predicted 906th Voxel
# Predicted 907th Voxel
# Predicted 908th Voxel
# Predicted 909th Voxel
# Predicted 910th Voxel
# Predicted 911th Voxel
# Predicted 912th Voxel
# Predicted 913th Voxel
# Predicted 914th Voxel
# Predicted 915th Voxel
# Predicted 916th Voxel
# Predicted 917th Voxel
# Predicted 918th Voxel
# Predicted 919th Voxel
# Predicted 920th Voxel
# Predicted 921th Voxel
# Predicted 922th Voxel
# Predicted 923th Voxel
# Predicted 924th Voxel
# Predicted 925th Voxel
# Predicted 926th Voxel
# Predicted 927th Voxel
# Predicted 928th Voxel
# Predicted 929th Voxel
# Predicted 930th Voxel
# Predicted 931th Voxel
# Predicted 932th Voxel
# Predicted 933th Voxel
# Predicted 934th Voxel
# Predicted 935th Voxel
# Predicted 936th Voxel
# Predicted 937th Voxel
# Predicted 938th Voxel
# Predicted 939th Voxel
# Predicted 940th Voxel
# Predicted 941th Voxel
# Predicted 942th Voxel
# Predicted 943th Voxel
# Predicted 944th Voxel
# Predicted 945th Voxel
# Predicted 946th Voxel
# Predicted 947th Voxel
# Predicted 948th Voxel
# Predicted 949th Voxel
# Predicted 950th Voxel
# Predicted 951th Voxel
# Predicted 952th Voxel
# Predicted 953th Voxel
# Predicted 954th Voxel
# Predicted 955th Voxel
# Predicted 956th Voxel
# Predicted 957th Voxel
# Predicted 958th Voxel
# Predicted 959th Voxel
# Predicted 960th Voxel
# Predicted 961th Voxel
# Predicted 962th Voxel
# Predicted 963th Voxel
# Predicted 964th Voxel
# Predicted 965th Voxel
# Predicted 966th Voxel
# Predicted 967th Voxel
# Predicted 968th Voxel
# Predicted 969th Voxel
# Predicted 970th Voxel
# Predicted 971th Voxel
# Predicted 972th Voxel
# Predicted 973th Voxel
# Predicted 974th Voxel
# Predicted 975th Voxel
# Predicted 976th Voxel
# Predicted 977th Voxel
# Predicted 978th Voxel
# Predicted 979th Voxel
# Predicted 980th Voxel
# Predicted 981th Voxel
# Predicted 982th Voxel
# Predicted 983th Voxel
# Predicted 984th Voxel
# Predicted 985th Voxel
# Predicted 986th Voxel
# Predicted 987th Voxel
# Predicted 988th Voxel
# Predicted 989th Voxel
# Predicted 990th Voxel
# Predicted 991th Voxel
# Predicted 992th Voxel
# Predicted 993th Voxel
# Predicted 994th Voxel
# Predicted 995th Voxel
# Predicted 996th Voxel
# Predicted 997th Voxel
# Predicted 998th Voxel
# Predicted 999th Voxel
# Predicted 1000th Voxel
# Predicted 1001th Voxel
# Predicted 1002th Voxel
# Predicted 1003th Voxel
# Predicted 1004th Voxel
# Predicted 1005th Voxel
# Predicted 1006th Voxel
# Predicted 1007th Voxel
# Predicted 1008th Voxel
# Predicted 1009th Voxel
# Predicted 1010th Voxel
# Predicted 1011th Voxel
# Predicted 1012th Voxel
# Predicted 1013th Voxel
# Predicted 1014th Voxel
# Predicted 1015th Voxel
# Predicted 1016th Voxel
# Predicted 1017th Voxel
# Predicted 1018th Voxel
# Predicted 1019th Voxel
# Predicted 1020th Voxel
# Predicted 1021th Voxel
# Predicted 1022th Voxel
# Predicted 1023th Voxel
# Predicted 1024th Voxel
# Predicted 1025th Voxel
# Predicted 1026th Voxel
# Predicted 1027th Voxel
# Predicted 1028th Voxel
# Predicted 1029th Voxel
# Predicted 1030th Voxel
# Predicted 1031th Voxel
# Predicted 1032th Voxel
# Predicted 1033th Voxel
# Predicted 1034th Voxel
# Predicted 1035th Voxel
# Predicted 1036th Voxel
# Predicted 1037th Voxel
# Predicted 1038th Voxel
# Predicted 1039th Voxel
# Predicted 1040th Voxel
# Predicted 1041th Voxel
# Predicted 1042th Voxel
# Predicted 1043th Voxel
# Predicted 1044th Voxel
# Predicted 1045th Voxel
# Predicted 1046th Voxel
# Predicted 1047th Voxel
# Predicted 1048th Voxel
# Predicted 1049th Voxel
# Predicted 1050th Voxel
# Predicted 1051th Voxel
# Predicted 1052th Voxel
# Predicted 1053th Voxel
# Predicted 1054th Voxel
# Predicted 1055th Voxel
# Predicted 1056th Voxel
# Predicted 1057th Voxel
# Predicted 1058th Voxel
# Predicted 1059th Voxel
# Predicted 1060th Voxel
# Predicted 1061th Voxel
# Predicted 1062th Voxel
# Predicted 1063th Voxel
# Predicted 1064th Voxel
# Predicted 1065th Voxel
# Predicted 1066th Voxel
# Predicted 1067th Voxel
# Predicted 1068th Voxel
# Predicted 1069th Voxel
# Predicted 1070th Voxel
# Predicted 1071th Voxel
# Predicted 1072th Voxel
# Predicted 1073th Voxel
# Predicted 1074th Voxel
# Predicted 1075th Voxel
# Predicted 1076th Voxel
# Predicted 1077th Voxel
# Predicted 1078th Voxel
# Predicted 1079th Voxel
# Predicted 1080th Voxel
# Predicted 1081th Voxel
# Predicted 1082th Voxel
# Predicted 1083th Voxel
# Predicted 1084th Voxel
# Predicted 1085th Voxel
# Predicted 1086th Voxel
# Predicted 1087th Voxel
# Predicted 1088th Voxel
# Predicted 1089th Voxel
# Predicted 1090th Voxel
# Predicted 1091th Voxel
# Predicted 1092th Voxel
# Predicted 1093th Voxel
# Predicted 1094th Voxel
# Predicted 1095th Voxel
# Predicted 1096th Voxel
# Predicted 1097th Voxel
# Predicted 1098th Voxel
# Predicted 1099th Voxel
# Predicted 1100th Voxel
# Predicted 1101th Voxel
# Predicted 1102th Voxel
# Predicted 1103th Voxel
# Predicted 1104th Voxel
# Predicted 1105th Voxel
# Predicted 1106th Voxel
# Predicted 1107th Voxel
# Predicted 1108th Voxel
# Predicted 1109th Voxel
# Predicted 1110th Voxel
# Predicted 1111th Voxel
# Predicted 1112th Voxel
# Predicted 1113th Voxel
# Predicted 1114th Voxel
# Predicted 1115th Voxel
# Predicted 1116th Voxel
# Predicted 1117th Voxel
# Predicted 1118th Voxel
# Predicted 1119th Voxel
# Predicted 1120th Voxel
# Predicted 1121th Voxel
# Predicted 1122th Voxel
# Predicted 1123th Voxel
# Predicted 1124th Voxel
# Predicted 1125th Voxel
# Predicted 1126th Voxel
# Predicted 1127th Voxel
# Predicted 1128th Voxel
# Predicted 1129th Voxel
# Predicted 1130th Voxel
# Predicted 1131th Voxel
# Predicted 1132th Voxel
# Predicted 1133th Voxel
# Predicted 1134th Voxel
# Predicted 1135th Voxel
# Predicted 1136th Voxel
# Predicted 1137th Voxel
# Predicted 1138th Voxel
# Predicted 1139th Voxel
# Predicted 1140th Voxel
# Predicted 1141th Voxel
# Predicted 1142th Voxel
# Predicted 1143th Voxel
# Predicted 1144th Voxel
# Predicted 1145th Voxel
# Predicted 1146th Voxel
# Predicted 1147th Voxel
# Predicted 1148th Voxel
# Predicted 1149th Voxel
# Predicted 1150th Voxel
# Predicted 1151th Voxel
# Predicted 1152th Voxel
# Predicted 1153th Voxel
# Predicted 1154th Voxel
# Predicted 1155th Voxel
# Predicted 1156th Voxel
# Predicted 1157th Voxel
# Predicted 1158th Voxel
# Predicted 1159th Voxel
# Predicted 1160th Voxel
# Predicted 1161th Voxel
# Predicted 1162th Voxel
# Predicted 1163th Voxel
# Predicted 1164th Voxel
# Predicted 1165th Voxel
# Predicted 1166th Voxel
# Predicted 1167th Voxel
# Predicted 1168th Voxel
# Predicted 1169th Voxel
# Predicted 1170th Voxel
# Predicted 1171th Voxel
# Predicted 1172th Voxel
# Predicted 1173th Voxel
# Predicted 1174th Voxel
# Predicted 1175th Voxel
# Predicted 1176th Voxel
# Predicted 1177th Voxel
# Predicted 1178th Voxel
# Predicted 1179th Voxel
# Predicted 1180th Voxel
# Predicted 1181th Voxel
# Predicted 1182th Voxel
# Predicted 1183th Voxel
# Predicted 1184th Voxel
# Predicted 1185th Voxel
# Predicted 1186th Voxel
# Predicted 1187th Voxel
# Predicted 1188th Voxel
# Predicted 1189th Voxel
# Predicted 1190th Voxel
# Predicted 1191th Voxel
# Predicted 1192th Voxel
# Predicted 1193th Voxel
# Predicted 1194th Voxel
# Predicted 1195th Voxel
# Predicted 1196th Voxel
# Predicted 1197th Voxel
# Predicted 1198th Voxel
# Predicted 1199th Voxel
# Predicted 1200th Voxel
# Predicted 1201th Voxel
# Predicted 1202th Voxel
# Predicted 1203th Voxel
# Predicted 1204th Voxel
# Predicted 1205th Voxel
# Predicted 1206th Voxel
# Predicted 1207th Voxel
# Predicted 1208th Voxel
# Predicted 1209th Voxel
# Predicted 1210th Voxel
# Predicted 1211th Voxel
# Predicted 1212th Voxel
# Predicted 1213th Voxel
# Predicted 1214th Voxel
# Predicted 1215th Voxel
# Predicted 1216th Voxel
# Predicted 1217th Voxel
# Predicted 1218th Voxel
# Predicted 1219th Voxel
# Predicted 1220th Voxel
# Predicted 1221th Voxel
# Predicted 1222th Voxel
# Predicted 1223th Voxel
# Predicted 1224th Voxel
# Predicted 1225th Voxel
# Predicted 1226th Voxel
# Predicted 1227th Voxel
# Predicted 1228th Voxel
# Predicted 1229th Voxel
# Predicted 1230th Voxel
# Predicted 1231th Voxel
# Predicted 1232th Voxel
# Predicted 1233th Voxel
# Predicted 1234th Voxel
# Predicted 1235th Voxel
# Predicted 1236th Voxel
# Predicted 1237th Voxel
# Predicted 1238th Voxel
# Predicted 1239th Voxel
# Predicted 1240th Voxel
# Predicted 1241th Voxel
# Predicted 1242th Voxel
# Predicted 1243th Voxel
# Predicted 1244th Voxel
# Predicted 1245th Voxel
# Predicted 1246th Voxel
# Predicted 1247th Voxel
# Predicted 1248th Voxel
# Predicted 1249th Voxel
# Predicted 1250th Voxel
# Predicted 1251th Voxel
# Predicted 1252th Voxel
# Predicted 1253th Voxel
# Predicted 1254th Voxel
# Predicted 1255th Voxel
# Predicted 1256th Voxel
# Predicted 1257th Voxel
# Predicted 1258th Voxel
# Predicted 1259th Voxel
# Predicted 1260th Voxel
# Predicted 1261th Voxel
# Predicted 1262th Voxel
# Predicted 1263th Voxel
# Predicted 1264th Voxel
# Predicted 1265th Voxel
# Predicted 1266th Voxel
# Predicted 1267th Voxel
# Predicted 1268th Voxel
# Predicted 1269th Voxel
# Predicted 1270th Voxel
# Predicted 1271th Voxel
# Predicted 1272th Voxel
# Predicted 1273th Voxel
# Predicted 1274th Voxel
# Predicted 1275th Voxel
# Predicted 1276th Voxel
# Predicted 1277th Voxel
# Predicted 1278th Voxel
# Predicted 1279th Voxel
# Predicted 1280th Voxel
# Predicted 1281th Voxel
# Predicted 1282th Voxel
# Predicted 1283th Voxel
# Predicted 1284th Voxel
# Predicted 1285th Voxel
# Predicted 1286th Voxel
# Predicted 1287th Voxel
# Predicted 1288th Voxel
# Predicted 1289th Voxel
# Predicted 1290th Voxel
# Predicted 1291th Voxel
# Predicted 1292th Voxel
# Predicted 1293th Voxel
# Predicted 1294th Voxel
# Predicted 1295th Voxel
# Predicted 1296th Voxel
# Predicted 1297th Voxel
# Predicted 1298th Voxel
# Predicted 1299th Voxel
# Predicted 1300th Voxel
# Predicted 1301th Voxel
# Predicted 1302th Voxel
# Predicted 1303th Voxel
# Predicted 1304th Voxel
# Predicted 1305th Voxel
# Predicted 1306th Voxel
# Predicted 1307th Voxel
# Predicted 1308th Voxel
# Predicted 1309th Voxel
# Predicted 1310th Voxel
# Predicted 1311th Voxel
# Predicted 1312th Voxel
# Predicted 1313th Voxel
# Predicted 1314th Voxel
# Predicted 1315th Voxel
# Predicted 1316th Voxel
# Predicted 1317th Voxel
# Predicted 1318th Voxel
# Predicted 1319th Voxel
# Predicted 1320th Voxel
# Predicted 1321th Voxel
# Predicted 1322th Voxel
# Predicted 1323th Voxel
# Predicted 1324th Voxel
# Predicted 1325th Voxel
# Predicted 1326th Voxel
# Predicted 1327th Voxel
# Predicted 1328th Voxel
# Predicted 1329th Voxel
# Predicted 1330th Voxel
# Predicted 1331th Voxel
# Predicted 1332th Voxel
# Predicted 1333th Voxel
# Predicted 1334th Voxel
# Predicted 1335th Voxel
# Predicted 1336th Voxel
# Predicted 1337th Voxel
# Predicted 1338th Voxel
# Predicted 1339th Voxel
# Predicted 1340th Voxel
# Predicted 1341th Voxel
# Predicted 1342th Voxel
# Predicted 1343th Voxel
# Predicted 1344th Voxel
# Predicted 1345th Voxel
# Predicted 1346th Voxel
# Predicted 1347th Voxel
# Predicted 1348th Voxel
# Predicted 1349th Voxel
# Predicted 1350th Voxel
# Predicted 1351th Voxel
# Predicted 1352th Voxel
# Predicted 1353th Voxel
# Predicted 1354th Voxel
# Predicted 1355th Voxel
# Predicted 1356th Voxel
# Predicted 1357th Voxel
# Predicted 1358th Voxel
# Predicted 1359th Voxel
# Predicted 1360th Voxel
# Predicted 1361th Voxel
# Predicted 1362th Voxel
# Predicted 1363th Voxel
# Predicted 1364th Voxel
# Predicted 1365th Voxel
# Predicted 1366th Voxel
# Predicted 1367th Voxel
# Predicted 1368th Voxel
# Predicted 1369th Voxel
# Predicted 1370th Voxel
# Predicted 1371th Voxel
# Predicted 1372th Voxel
# Predicted 1373th Voxel
# Predicted 1374th Voxel
# Predicted 1375th Voxel
# Predicted 1376th Voxel
# Predicted 1377th Voxel
# Predicted 1378th Voxel
# Predicted 1379th Voxel
# Predicted 1380th Voxel
# Predicted 1381th Voxel
# Predicted 1382th Voxel
# Predicted 1383th Voxel
# Predicted 1384th Voxel
# Predicted 1385th Voxel
# Predicted 1386th Voxel
# Predicted 1387th Voxel
# Predicted 1388th Voxel
# Predicted 1389th Voxel
# Predicted 1390th Voxel
# Predicted 1391th Voxel
# Predicted 1392th Voxel
# Predicted 1393th Voxel
# Predicted 1394th Voxel
# Predicted 1395th Voxel
# Predicted 1396th Voxel
# Predicted 1397th Voxel
# Predicted 1398th Voxel
# Predicted 1399th Voxel
# Predicted 1400th Voxel
# Predicted 1401th Voxel
# Predicted 1402th Voxel
# Predicted 1403th Voxel
# Predicted 1404th Voxel
# Predicted 1405th Voxel
# Predicted 1406th Voxel
# Predicted 1407th Voxel
# Predicted 1408th Voxel
# Predicted 1409th Voxel
# Predicted 1410th Voxel
# Predicted 1411th Voxel
# Predicted 1412th Voxel
# Predicted 1413th Voxel
# Predicted 1414th Voxel
# Predicted 1415th Voxel
# Predicted 1416th Voxel
# Predicted 1417th Voxel
# Predicted 1418th Voxel
# Predicted 1419th Voxel
# Predicted 1420th Voxel
# Predicted 1421th Voxel
# Predicted 1422th Voxel
# Predicted 1423th Voxel
# Predicted 1424th Voxel
# Predicted 1425th Voxel
# Predicted 1426th Voxel
# Predicted 1427th Voxel
# Predicted 1428th Voxel
# Predicted 1429th Voxel
# Predicted 1430th Voxel
# Predicted 1431th Voxel
# Predicted 1432th Voxel
# Predicted 1433th Voxel
# Predicted 1434th Voxel
# Predicted 1435th Voxel
# Predicted 1436th Voxel
# Predicted 1437th Voxel
# Predicted 1438th Voxel
# Predicted 1439th Voxel
# Predicted 1440th Voxel
# Predicted 1441th Voxel
# Predicted 1442th Voxel
# Predicted 1443th Voxel
# Predicted 1444th Voxel
# Predicted 1445th Voxel
# Predicted 1446th Voxel
# Predicted 1447th Voxel
# Predicted 1448th Voxel
# Predicted 1449th Voxel
# Predicted 1450th Voxel
# Predicted 1451th Voxel
# Predicted 1452th Voxel
# Predicted 1453th Voxel
# Predicted 1454th Voxel
# Predicted 1455th Voxel
# Predicted 1456th Voxel
# Predicted 1457th Voxel
# Predicted 1458th Voxel
# Predicted 1459th Voxel
# Predicted 1460th Voxel
# Predicted 1461th Voxel
# Predicted 1462th Voxel
# Predicted 1463th Voxel
# Predicted 1464th Voxel
# Predicted 1465th Voxel
# Predicted 1466th Voxel
# Predicted 1467th Voxel
# Predicted 1468th Voxel
# Predicted 1469th Voxel
# Predicted 1470th Voxel
# Predicted 1471th Voxel
# Predicted 1472th Voxel
# Predicted 1473th Voxel
# Predicted 1474th Voxel
# Predicted 1475th Voxel
# Predicted 1476th Voxel
# Predicted 1477th Voxel
# Predicted 1478th Voxel
# Predicted 1479th Voxel
# Predicted 1480th Voxel
# Predicted 1481th Voxel
# Predicted 1482th Voxel
# Predicted 1483th Voxel
# Predicted 1484th Voxel
# Predicted 1485th Voxel
# Predicted 1486th Voxel
# Predicted 1487th Voxel
# Predicted 1488th Voxel
# Predicted 1489th Voxel
# Predicted 1490th Voxel
# Predicted 1491th Voxel
# Predicted 1492th Voxel
# Predicted 1493th Voxel
# Predicted 1494th Voxel
# Predicted 1495th Voxel
# Predicted 1496th Voxel
# Predicted 1497th Voxel
# Predicted 1498th Voxel
# Predicted 1499th Voxel
# Predicted 1500th Voxel
# Predicted 1501th Voxel
# Predicted 1502th Voxel
# Predicted 1503th Voxel
# Predicted 1504th Voxel
# Predicted 1505th Voxel
# Predicted 1506th Voxel
# Predicted 1507th Voxel
# Predicted 1508th Voxel
# Predicted 1509th Voxel
# Predicted 1510th Voxel
# Predicted 1511th Voxel
# Predicted 1512th Voxel
# Predicted 1513th Voxel
# Predicted 1514th Voxel
# Predicted 1515th Voxel
# Predicted 1516th Voxel
# Predicted 1517th Voxel
# Predicted 1518th Voxel
# Predicted 1519th Voxel
# Predicted 1520th Voxel
# Predicted 1521th Voxel
# Predicted 1522th Voxel
# Predicted 1523th Voxel
# Predicted 1524th Voxel
# Predicted 1525th Voxel
# Predicted 1526th Voxel
# Predicted 1527th Voxel
# Predicted 1528th Voxel
# Predicted 1529th Voxel
# Predicted 1530th Voxel
# Predicted 1531th Voxel
# Predicted 1532th Voxel
# Predicted 1533th Voxel
# Predicted 1534th Voxel
# Predicted 1535th Voxel
# Predicted 1536th Voxel
# Predicted 1537th Voxel
# Predicted 1538th Voxel
# Predicted 1539th Voxel
# Predicted 1540th Voxel
# Predicted 1541th Voxel
# Predicted 1542th Voxel
# Predicted 1543th Voxel
# Predicted 1544th Voxel
# Predicted 1545th Voxel
# Predicted 1546th Voxel
# Predicted 1547th Voxel
# Predicted 1548th Voxel
# Predicted 1549th Voxel
# Predicted 1550th Voxel
# Predicted 1551th Voxel
# Predicted 1552th Voxel
# Predicted 1553th Voxel
# Predicted 1554th Voxel
# Predicted 1555th Voxel
# Predicted 1556th Voxel
# Predicted 1557th Voxel
# Predicted 1558th Voxel
# Predicted 1559th Voxel
# Predicted 1560th Voxel
# Predicted 1561th Voxel
# Predicted 1562th Voxel
# Predicted 1563th Voxel
# Predicted 1564th Voxel
# Predicted 1565th Voxel
# Predicted 1566th Voxel
# Predicted 1567th Voxel
# Predicted 1568th Voxel
# Predicted 1569th Voxel
# Predicted 1570th Voxel
# Predicted 1571th Voxel
# Predicted 1572th Voxel
# Predicted 1573th Voxel
# Predicted 1574th Voxel
# Predicted 1575th Voxel
# Predicted 1576th Voxel
# Predicted 1577th Voxel
# Predicted 1578th Voxel
# Predicted 1579th Voxel
# Predicted 1580th Voxel
# Predicted 1581th Voxel
# Predicted 1582th Voxel
# Predicted 1583th Voxel
# Predicted 1584th Voxel
# Predicted 1585th Voxel
# Predicted 1586th Voxel
# Predicted 1587th Voxel
# Predicted 1588th Voxel
# Predicted 1589th Voxel
# Predicted 1590th Voxel
# Predicted 1591th Voxel
# Predicted 1592th Voxel
# Predicted 1593th Voxel
# Predicted 1594th Voxel
# Predicted 1595th Voxel
# Predicted 1596th Voxel
# Predicted 1597th Voxel
# Predicted 1598th Voxel
# Predicted 1599th Voxel
# Predicted 1600th Voxel
# Predicted 1601th Voxel
# Predicted 1602th Voxel
# Predicted 1603th Voxel
# Predicted 1604th Voxel
# Predicted 1605th Voxel
# Predicted 1606th Voxel
# Predicted 1607th Voxel
# Predicted 1608th Voxel
# Predicted 1609th Voxel
# Predicted 1610th Voxel
# Predicted 1611th Voxel
# Predicted 1612th Voxel
# Predicted 1613th Voxel
# Predicted 1614th Voxel
# Predicted 1615th Voxel
# Predicted 1616th Voxel
# Predicted 1617th Voxel
# Predicted 1618th Voxel
# Predicted 1619th Voxel
# Predicted 1620th Voxel
# Predicted 1621th Voxel
# Predicted 1622th Voxel
# Predicted 1623th Voxel
# Predicted 1624th Voxel
# Predicted 1625th Voxel
# Predicted 1626th Voxel
# Predicted 1627th Voxel
# Predicted 1628th Voxel
# Predicted 1629th Voxel
# Predicted 1630th Voxel
# Predicted 1631th Voxel
# Predicted 1632th Voxel
# Predicted 1633th Voxel
# Predicted 1634th Voxel
# Predicted 1635th Voxel
# Predicted 1636th Voxel
# Predicted 1637th Voxel
# Predicted 1638th Voxel
# Predicted 1639th Voxel
# Predicted 1640th Voxel
# Predicted 1641th Voxel
# Predicted 1642th Voxel
# Predicted 1643th Voxel
# Predicted 1644th Voxel
# Predicted 1645th Voxel
# Predicted 1646th Voxel
# Predicted 1647th Voxel
# Predicted 1648th Voxel
# Predicted 1649th Voxel
# Predicted 1650th Voxel
# Predicted 1651th Voxel
# Predicted 1652th Voxel
# Predicted 1653th Voxel
# Predicted 1654th Voxel
# Predicted 1655th Voxel
# Predicted 1656th Voxel
# Predicted 1657th Voxel
# Predicted 1658th Voxel
# Predicted 1659th Voxel
# Predicted 1660th Voxel
# Predicted 1661th Voxel
# Predicted 1662th Voxel
# Predicted 1663th Voxel
# Predicted 1664th Voxel
# Predicted 1665th Voxel
# Predicted 1666th Voxel
# Predicted 1667th Voxel
# Predicted 1668th Voxel
# Predicted 1669th Voxel
# Predicted 1670th Voxel
# Predicted 1671th Voxel
# Predicted 1672th Voxel
# Predicted 1673th Voxel
# Predicted 1674th Voxel
# Predicted 1675th Voxel
# Predicted 1676th Voxel
# Predicted 1677th Voxel
# Predicted 1678th Voxel
# Predicted 1679th Voxel
# Predicted 1680th Voxel
# Predicted 1681th Voxel
# Predicted 1682th Voxel
# Predicted 1683th Voxel
# Predicted 1684th Voxel
# Predicted 1685th Voxel
# Predicted 1686th Voxel
# Predicted 1687th Voxel
# Predicted 1688th Voxel
# Predicted 1689th Voxel
# Predicted 1690th Voxel
# Predicted 1691th Voxel
# Predicted 1692th Voxel
# Predicted 1693th Voxel
# Predicted 1694th Voxel
# Predicted 1695th Voxel
# Predicted 1696th Voxel
# Predicted 1697th Voxel
# Predicted 1698th Voxel
# Predicted 1699th Voxel
# Predicted 1700th Voxel
# Predicted 1701th Voxel
# Predicted 1702th Voxel
# Predicted 1703th Voxel
# Predicted 1704th Voxel
# Predicted 1705th Voxel
# Predicted 1706th Voxel
# Predicted 1707th Voxel
# Predicted 1708th Voxel
# Predicted 1709th Voxel
# Predicted 1710th Voxel
# Predicted 1711th Voxel
# Predicted 1712th Voxel
# Predicted 1713th Voxel
# Predicted 1714th Voxel
# Predicted 1715th Voxel
# Predicted 1716th Voxel
# Predicted 1717th Voxel
# Predicted 1718th Voxel
# Predicted 1719th Voxel
# Predicted 1720th Voxel
# Predicted 1721th Voxel
# Predicted 1722th Voxel
# Predicted 1723th Voxel
# Predicted 1724th Voxel
# Predicted 1725th Voxel
# Predicted 1726th Voxel
# Predicted 1727th Voxel
# Predicted 1728th Voxel
# Predicted 1729th Voxel
# Predicted 1730th Voxel
# Predicted 1731th Voxel
# Predicted 1732th Voxel
# Predicted 1733th Voxel
# Predicted 1734th Voxel
# Predicted 1735th Voxel
# Predicted 1736th Voxel
# Predicted 1737th Voxel
# Predicted 1738th Voxel
# Predicted 1739th Voxel
# Predicted 1740th Voxel
# Predicted 1741th Voxel
# Predicted 1742th Voxel
# Predicted 1743th Voxel
# Predicted 1744th Voxel
# Predicted 1745th Voxel
# Predicted 1746th Voxel
# Predicted 1747th Voxel
# Predicted 1748th Voxel
# Predicted 1749th Voxel
# Predicted 1750th Voxel
# Predicted 1751th Voxel
# Predicted 1752th Voxel
# Predicted 1753th Voxel
# Predicted 1754th Voxel
# Predicted 1755th Voxel
# Predicted 1756th Voxel
# Predicted 1757th Voxel
# Predicted 1758th Voxel
# Predicted 1759th Voxel
# Predicted 1760th Voxel
# Predicted 1761th Voxel
# Predicted 1762th Voxel
# Predicted 1763th Voxel
# Predicted 1764th Voxel
# Predicted 1765th Voxel
# Predicted 1766th Voxel
# Predicted 1767th Voxel
# Predicted 1768th Voxel
# Predicted 1769th Voxel
# Predicted 1770th Voxel
# Predicted 1771th Voxel
# Predicted 1772th Voxel
# Predicted 1773th Voxel
# Predicted 1774th Voxel
# Predicted 1775th Voxel
# Predicted 1776th Voxel
# Predicted 1777th Voxel
# Predicted 1778th Voxel
# Predicted 1779th Voxel
# Predicted 1780th Voxel
# Predicted 1781th Voxel
# Predicted 1782th Voxel
# Predicted 1783th Voxel
# Predicted 1784th Voxel
# Predicted 1785th Voxel
# Predicted 1786th Voxel
# Predicted 1787th Voxel
# Predicted 1788th Voxel
# Predicted 1789th Voxel
# Predicted 1790th Voxel
# Predicted 1791th Voxel
# Predicted 1792th Voxel
# Predicted 1793th Voxel
# Predicted 1794th Voxel
# Predicted 1795th Voxel
# Predicted 1796th Voxel
# Predicted 1797th Voxel
# Predicted 1798th Voxel
# Predicted 1799th Voxel
# Predicted 1800th Voxel
# Predicted 1801th Voxel
# Predicted 1802th Voxel
# Predicted 1803th Voxel
# Predicted 1804th Voxel
# Predicted 1805th Voxel
# Predicted 1806th Voxel
# Predicted 1807th Voxel
# Predicted 1808th Voxel
# Predicted 1809th Voxel
# Predicted 1810th Voxel
# Predicted 1811th Voxel
# Predicted 1812th Voxel
# Predicted 1813th Voxel
# Predicted 1814th Voxel
# Predicted 1815th Voxel
# Predicted 1816th Voxel
# Predicted 1817th Voxel
# Predicted 1818th Voxel
# Predicted 1819th Voxel
# Predicted 1820th Voxel
# Predicted 1821th Voxel
# Predicted 1822th Voxel
# Predicted 1823th Voxel
# Predicted 1824th Voxel
# Predicted 1825th Voxel
# Predicted 1826th Voxel
# Predicted 1827th Voxel
# Predicted 1828th Voxel
# Predicted 1829th Voxel
# Predicted 1830th Voxel
# Predicted 1831th Voxel
# Predicted 1832th Voxel
# Predicted 1833th Voxel
# Predicted 1834th Voxel
# Predicted 1835th Voxel
# Predicted 1836th Voxel
# Predicted 1837th Voxel
# Predicted 1838th Voxel
# Predicted 1839th Voxel
# Predicted 1840th Voxel
# Predicted 1841th Voxel
# Predicted 1842th Voxel
# Predicted 1843th Voxel
# Predicted 1844th Voxel
# Predicted 1845th Voxel
# Predicted 1846th Voxel
# Predicted 1847th Voxel
# Predicted 1848th Voxel
# Predicted 1849th Voxel
# Predicted 1850th Voxel
# Predicted 1851th Voxel
# Predicted 1852th Voxel
# Predicted 1853th Voxel
# Predicted 1854th Voxel
# Predicted 1855th Voxel
# Predicted 1856th Voxel
# Predicted 1857th Voxel
# Predicted 1858th Voxel
# Predicted 1859th Voxel
# Predicted 1860th Voxel
# Predicted 1861th Voxel
# Predicted 1862th Voxel
# Predicted 1863th Voxel
# Predicted 1864th Voxel
# Predicted 1865th Voxel
# Predicted 1866th Voxel
# Predicted 1867th Voxel
# Predicted 1868th Voxel
# Predicted 1869th Voxel
# Predicted 1870th Voxel
# Predicted 1871th Voxel
# Predicted 1872th Voxel
# Predicted 1873th Voxel
# Predicted 1874th Voxel
# Predicted 1875th Voxel
# Predicted 1876th Voxel
# Predicted 1877th Voxel
# Predicted 1878th Voxel
# Predicted 1879th Voxel
# Predicted 1880th Voxel
# Predicted 1881th Voxel
# Predicted 1882th Voxel
# Predicted 1883th Voxel
# Predicted 1884th Voxel
# Predicted 1885th Voxel
# Predicted 1886th Voxel
# Predicted 1887th Voxel
# Predicted 1888th Voxel
# Predicted 1889th Voxel
# Predicted 1890th Voxel
# Predicted 1891th Voxel
# Predicted 1892th Voxel
# Predicted 1893th Voxel
# Predicted 1894th Voxel
# Predicted 1895th Voxel
# Predicted 1896th Voxel
# Predicted 1897th Voxel
# Predicted 1898th Voxel
# Predicted 1899th Voxel
# Predicted 1900th Voxel
# Predicted 1901th Voxel
# Predicted 1902th Voxel
# Predicted 1903th Voxel
# Predicted 1904th Voxel
# Predicted 1905th Voxel
# Predicted 1906th Voxel
# Predicted 1907th Voxel
# Predicted 1908th Voxel
# Predicted 1909th Voxel
# Predicted 1910th Voxel
# Predicted 1911th Voxel
# Predicted 1912th Voxel
# Predicted 1913th Voxel
# Predicted 1914th Voxel
# Predicted 1915th Voxel
# Predicted 1916th Voxel
# Predicted 1917th Voxel
# Predicted 1918th Voxel
# Predicted 1919th Voxel
# Predicted 1920th Voxel
# Predicted 1921th Voxel
# Predicted 1922th Voxel
# Predicted 1923th Voxel
# Predicted 1924th Voxel
# Predicted 1925th Voxel
# Predicted 1926th Voxel
# Predicted 1927th Voxel
# Predicted 1928th Voxel
# Predicted 1929th Voxel
# Predicted 1930th Voxel
# Predicted 1931th Voxel
# Predicted 1932th Voxel
# Predicted 1933th Voxel
# Predicted 1934th Voxel
# Predicted 1935th Voxel
# Predicted 1936th Voxel
# Predicted 1937th Voxel
# Predicted 1938th Voxel
# Predicted 1939th Voxel
# Predicted 1940th Voxel
# Predicted 1941th Voxel
# Predicted 1942th Voxel
# Predicted 1943th Voxel
# Predicted 1944th Voxel
# Predicted 1945th Voxel
# Predicted 1946th Voxel
# Predicted 1947th Voxel
# Predicted 1948th Voxel
# Predicted 1949th Voxel
# Predicted 1950th Voxel
# Predicted 1951th Voxel
# Predicted 1952th Voxel
# Predicted 1953th Voxel
# Predicted 1954th Voxel
# Predicted 1955th Voxel
# Predicted 1956th Voxel
# Predicted 1957th Voxel
# Predicted 1958th Voxel
# Predicted 1959th Voxel
# Predicted 1960th Voxel
# Predicted 1961th Voxel
# Predicted 1962th Voxel
# Predicted 1963th Voxel
# Predicted 1964th Voxel
# Predicted 1965th Voxel
# Predicted 1966th Voxel
# Predicted 1967th Voxel
# Predicted 1968th Voxel
# Predicted 1969th Voxel
# Predicted 1970th Voxel
# Predicted 1971th Voxel
# Predicted 1972th Voxel
# Predicted 1973th Voxel
# Predicted 1974th Voxel
# Predicted 1975th Voxel
# Predicted 1976th Voxel
# Predicted 1977th Voxel
# Predicted 1978th Voxel
# Predicted 1979th Voxel
# Predicted 1980th Voxel
# Predicted 1981th Voxel
# Predicted 1982th Voxel
# Predicted 1983th Voxel
# Predicted 1984th Voxel
# Predicted 1985th Voxel
# Predicted 1986th Voxel
# Predicted 1987th Voxel
# Predicted 1988th Voxel
# Predicted 1989th Voxel
# Predicted 1990th Voxel
# Predicted 1991th Voxel
# Predicted 1992th Voxel
# Predicted 1993th Voxel
# Predicted 1994th Voxel
# Predicted 1995th Voxel
# Predicted 1996th Voxel
# Predicted 1997th Voxel
# Predicted 1998th Voxel
# Predicted 1999th Voxel
# Predicted 2000th Voxel
# Predicted 2001th Voxel
# Predicted 2002th Voxel
# Predicted 2003th Voxel
# Predicted 2004th Voxel
# Predicted 2005th Voxel
# Predicted 2006th Voxel
# Predicted 2007th Voxel
# Predicted 2008th Voxel
# Predicted 2009th Voxel
# Predicted 2010th Voxel
# Predicted 2011th Voxel
# Predicted 2012th Voxel
# Predicted 2013th Voxel
# Predicted 2014th Voxel
# Predicted 2015th Voxel
# Predicted 2016th Voxel
# Predicted 2017th Voxel
# Predicted 2018th Voxel
# Predicted 2019th Voxel
# Predicted 2020th Voxel
# Predicted 2021th Voxel
# Predicted 2022th Voxel
# Predicted 2023th Voxel
# Predicted 2024th Voxel
# Predicted 2025th Voxel
# Predicted 2026th Voxel
# Predicted 2027th Voxel
# Predicted 2028th Voxel
# Predicted 2029th Voxel
# Predicted 2030th Voxel
# Predicted 2031th Voxel
# Predicted 2032th Voxel
# Predicted 2033th Voxel
# Predicted 2034th Voxel
# Predicted 2035th Voxel
# Predicted 2036th Voxel
# Predicted 2037th Voxel
# Predicted 2038th Voxel
# Predicted 2039th Voxel
# Predicted 2040th Voxel
# Predicted 2041th Voxel
# Predicted 2042th Voxel
# Predicted 2043th Voxel
# Predicted 2044th Voxel
# Predicted 2045th Voxel
# Predicted 2046th Voxel
# Predicted 2047th Voxel
# Predicted 2048th Voxel
# Predicted 2049th Voxel
# Predicted 2050th Voxel
# Predicted 2051th Voxel
# Predicted 2052th Voxel
# Predicted 2053th Voxel
# Predicted 2054th Voxel
# Predicted 2055th Voxel
# Predicted 2056th Voxel
# Predicted 2057th Voxel
# Predicted 2058th Voxel
# Predicted 2059th Voxel
# Predicted 2060th Voxel
# Predicted 2061th Voxel
# Predicted 2062th Voxel
# Predicted 2063th Voxel
# Predicted 2064th Voxel
# Predicted 2065th Voxel
# Predicted 2066th Voxel
# Predicted 2067th Voxel
# Predicted 2068th Voxel
# Predicted 2069th Voxel
# Predicted 2070th Voxel
# Predicted 2071th Voxel
# Predicted 2072th Voxel
# Predicted 2073th Voxel
# Predicted 2074th Voxel
# Predicted 2075th Voxel
# Predicted 2076th Voxel
# Predicted 2077th Voxel
# Predicted 2078th Voxel
# Predicted 2079th Voxel
# Predicted 2080th Voxel
# Predicted 2081th Voxel
# Predicted 2082th Voxel
# Predicted 2083th Voxel
# Predicted 2084th Voxel
# Predicted 2085th Voxel
# Predicted 2086th Voxel
# Predicted 2087th Voxel
# Predicted 2088th Voxel
# Predicted 2089th Voxel
# Predicted 2090th Voxel
# Predicted 2091th Voxel
# Predicted 2092th Voxel
# Predicted 2093th Voxel
# Predicted 2094th Voxel
# Predicted 2095th Voxel
# Predicted 2096th Voxel
# Predicted 2097th Voxel
# Predicted 2098th Voxel
# Predicted 2099th Voxel
# Predicted 2100th Voxel
# Predicted 2101th Voxel
# Predicted 2102th Voxel
# Predicted 2103th Voxel
# Predicted 2104th Voxel
# Predicted 2105th Voxel
# Predicted 2106th Voxel
# Predicted 2107th Voxel
# Predicted 2108th Voxel
# Predicted 2109th Voxel
# Predicted 2110th Voxel
# Predicted 2111th Voxel
# Predicted 2112th Voxel
# Predicted 2113th Voxel
# Predicted 2114th Voxel
# Predicted 2115th Voxel
# Predicted 2116th Voxel
# Predicted 2117th Voxel
# Predicted 2118th Voxel
# Predicted 2119th Voxel
# Predicted 2120th Voxel
# Predicted 2121th Voxel
# Predicted 2122th Voxel
# Predicted 2123th Voxel
# Predicted 2124th Voxel
# Predicted 2125th Voxel
# Predicted 2126th Voxel
# Predicted 2127th Voxel
# Predicted 2128th Voxel
# Predicted 2129th Voxel
# Predicted 2130th Voxel
# Predicted 2131th Voxel
# ...
# Predicted 3078th Voxel
# Predicted 3079th Voxel
# Predicted 3080th Voxel
# Predicted 3081th Voxel
# Predicted 3082th Voxel
# Predicted 3083th Voxel
# Predicted 3084th Voxel
# Predicted 3085th Voxel
# Predicted 3086th Voxel
# Predicted 3087th Voxel
# Predicted 3088th Voxel
# Predicted 3089th Voxel
# Predicted 3090th Voxel
# Predicted 3091th Voxel
# Predicted 3092th Voxel
# Predicted 3093th Voxel
# Predicted 3094th Voxel
# Predicted 3095th Voxel
# Predicted 3096th Voxel
# Predicted 3097th Voxel
# Predicted 3098th Voxel
# Predicted 3099th Voxel
# Predicted 3100th Voxel
# Predicted 3101th Voxel
# Predicted 3102th Voxel
# Predicted 3103th Voxel
# Predicted 3104th Voxel
# Predicted 3105th Voxel
# Predicted 3106th Voxel
# Predicted 3107th Voxel
# Predicted 3108th Voxel
# Predicted 3109th Voxel
# Predicted 3110th Voxel
# Predicted 3111th Voxel
# Predicted 3112th Voxel
# Predicted 3113th Voxel
# Predicted 3114th Voxel
# Predicted 3115th Voxel
# Predicted 3116th Voxel
# Predicted 3117th Voxel
# Predicted 3118th Voxel
# Predicted 3119th Voxel
# Predicted 3120th Voxel
# Predicted 3121th Voxel
# Predicted 3122th Voxel
# Predicted 3123th Voxel
# Predicted 3124th Voxel
# Predicted 3125th Voxel
# Predicted 3126th Voxel
# Predicted 3127th Voxel
# Predicted 3128th Voxel
# Predicted 3129th Voxel
# Predicted 3130th Voxel
# Predicted 3131th Voxel
# Predicted 3132th Voxel
# Predicted 3133th Voxel
# Predicted 3134th Voxel
# Predicted 3135th Voxel
# Predicted 3136th Voxel
# Predicted 3137th Voxel
# Predicted 3138th Voxel
# Predicted 3139th Voxel
# Predicted 3140th Voxel
# Predicted 3141th Voxel
# Predicted 3142th Voxel
# Predicted 3143th Voxel
# Predicted 3144th Voxel
# Predicted 3145th Voxel
# Predicted 3146th Voxel
# Predicted 3147th Voxel
# Predicted 3148th Voxel
# Predicted 3149th Voxel
# Predicted 3150th Voxel
# Predicted 3151th Voxel
# Predicted 3152th Voxel
# Predicted 3153th Voxel
# Predicted 3154th Voxel
# Predicted 3155th Voxel
# Predicted 3156th Voxel
# Predicted 3157th Voxel
# Predicted 3158th Voxel
# Predicted 3159th Voxel
# Predicted 3160th Voxel
# Predicted 3161th Voxel
# Predicted 3162th Voxel
# Predicted 3163th Voxel
# Predicted 3164th Voxel
# Predicted 3165th Voxel
# Predicted 3166th Voxel
# Predicted 3167th Voxel
# Predicted 3168th Voxel
# Predicted 3169th Voxel
# Predicted 3170th Voxel
# Predicted 3171th Voxel
# Predicted 3172th Voxel
# Predicted 3173th Voxel
# Predicted 3174th Voxel
# Predicted 3175th Voxel
# Predicted 3176th Voxel
# Predicted 3177th Voxel
# Predicted 3178th Voxel
# Predicted 3179th Voxel
# Predicted 3180th Voxel
# Predicted 3181th Voxel
# Predicted 3182th Voxel
# Predicted 3183th Voxel
# Predicted 3184th Voxel
# Predicted 3185th Voxel
# Predicted 3186th Voxel
# Predicted 3187th Voxel
# Predicted 3188th Voxel
# Predicted 3189th Voxel
# Predicted 3190th Voxel
# Predicted 3191th Voxel
# Predicted 3192th Voxel
# Predicted 3193th Voxel
# Predicted 3194th Voxel
# Predicted 3195th Voxel
# Predicted 3196th Voxel
# Predicted 3197th Voxel
# Predicted 3198th Voxel
# Predicted 3199th Voxel
# Predicted 3200th Voxel
# Predicted 3201th Voxel
# Predicted 3202th Voxel
# Predicted 3203th Voxel
# Predicted 3204th Voxel
# Predicted 3205th Voxel
# Predicted 3206th Voxel
# Predicted 3207th Voxel
# Predicted 3208th Voxel
# Predicted 3209th Voxel
# Predicted 3210th Voxel
# Predicted 3211th Voxel
# Predicted 3212th Voxel
# Predicted 3213th Voxel
# Predicted 3214th Voxel
# Predicted 3215th Voxel
# Predicted 3216th Voxel
# Predicted 3217th Voxel
# Predicted 3218th Voxel
# Predicted 3219th Voxel
# Predicted 3220th Voxel
# Predicted 3221th Voxel
# Predicted 3222th Voxel
# Predicted 3223th Voxel
# Predicted 3224th Voxel
# Predicted 3225th Voxel
# Predicted 3226th Voxel
# Predicted 3227th Voxel
# Predicted 3228th Voxel
# Predicted 3229th Voxel
# Predicted 3230th Voxel
# Predicted 3231th Voxel
# Predicted 3232th Voxel
# Predicted 3233th Voxel
# Predicted 3234th Voxel
# Predicted 3235th Voxel
# Predicted 3236th Voxel
# Predicted 3237th Voxel
# Predicted 3238th Voxel
# Predicted 3239th Voxel
# Predicted 3240th Voxel
# Predicted 3241th Voxel
# Predicted 3242th Voxel
# Predicted 3243th Voxel
# Predicted 3244th Voxel
# Predicted 3245th Voxel
# Predicted 3246th Voxel
# Predicted 3247th Voxel
# Predicted 3248th Voxel
# Predicted 3249th Voxel
# Predicted 3250th Voxel
# Predicted 3251th Voxel
# Predicted 3252th Voxel
# Predicted 3253th Voxel
# Predicted 3254th Voxel
# Predicted 3255th Voxel
# Predicted 3256th Voxel
# Predicted 3257th Voxel
# Predicted 3258th Voxel
# Predicted 3259th Voxel
# Predicted 3260th Voxel
# Predicted 3261th Voxel
# Predicted 3262th Voxel
# Predicted 3263th Voxel
# Predicted 3264th Voxel
# Predicted 3265th Voxel
# Predicted 3266th Voxel
# Predicted 3267th Voxel
# Predicted 3268th Voxel
# Predicted 3269th Voxel
# Predicted 3270th Voxel
# Predicted 3271th Voxel
# Predicted 3272th Voxel
# Predicted 3273th Voxel
# Predicted 3274th Voxel
# Predicted 3275th Voxel
# Predicted 3276th Voxel
# Predicted 3277th Voxel
# Predicted 3278th Voxel
# Predicted 3279th Voxel
# Predicted 3280th Voxel
# Predicted 3281th Voxel
# Predicted 3282th Voxel
# Predicted 3283th Voxel
# Predicted 3284th Voxel
# Predicted 3285th Voxel
# Predicted 3286th Voxel
# Predicted 3287th Voxel
# Predicted 3288th Voxel
# Predicted 3289th Voxel
# Predicted 3290th Voxel
# Predicted 3291th Voxel
# Predicted 3292th Voxel
# Predicted 3293th Voxel
# Predicted 3294th Voxel
# Predicted 3295th Voxel
# Predicted 3296th Voxel
# Predicted 3297th Voxel
# Predicted 3298th Voxel
# Predicted 3299th Voxel
# Predicted 3300th Voxel
# Predicted 3301th Voxel
# Predicted 3302th Voxel
# Predicted 3303th Voxel
# Predicted 3304th Voxel
# Predicted 3305th Voxel
# Predicted 3306th Voxel
# Predicted 3307th Voxel
# Predicted 3308th Voxel
# Predicted 3309th Voxel
# Predicted 3310th Voxel
# Predicted 3311th Voxel
# Predicted 3312th Voxel
# Predicted 3313th Voxel
# Predicted 3314th Voxel
# Predicted 3315th Voxel
# Predicted 3316th Voxel
# Predicted 3317th Voxel
# Predicted 3318th Voxel
# Predicted 3319th Voxel
# Predicted 3320th Voxel
# Predicted 3321th Voxel
# Predicted 3322th Voxel
# Predicted 3323th Voxel
# Predicted 3324th Voxel
# Predicted 3325th Voxel
# Predicted 3326th Voxel
# Predicted 3327th Voxel
# Predicted 3328th Voxel
# Predicted 3329th Voxel
# Predicted 3330th Voxel
# Predicted 3331th Voxel
# Predicted 3332th Voxel
# Predicted 3333th Voxel
# Predicted 3334th Voxel
# Predicted 3335th Voxel
# Predicted 3336th Voxel
# Predicted 3337th Voxel
# Predicted 3338th Voxel
# Predicted 3339th Voxel
# Predicted 3340th Voxel
# Predicted 3341th Voxel
# Predicted 3342th Voxel
# Predicted 3343th Voxel
# Predicted 3344th Voxel
# Predicted 3345th Voxel
# Predicted 3346th Voxel
# Predicted 3347th Voxel
# Predicted 3348th Voxel
# Predicted 3349th Voxel
# Predicted 3350th Voxel
# Predicted 3351th Voxel
# Predicted 3352th Voxel
# Predicted 3353th Voxel
# Predicted 3354th Voxel
# Predicted 3355th Voxel
# Predicted 3356th Voxel
# Predicted 3357th Voxel
# Predicted 3358th Voxel
# Predicted 3359th Voxel
# Predicted 3360th Voxel
# Predicted 3361th Voxel
# Predicted 3362th Voxel
# Predicted 3363th Voxel
# Predicted 3364th Voxel
# Predicted 3365th Voxel
# Predicted 3366th Voxel
# Predicted 3367th Voxel
# Predicted 3368th Voxel
# Predicted 3369th Voxel
# Predicted 3370th Voxel
# Predicted 3371th Voxel
# Predicted 3372th Voxel
# Predicted 3373th Voxel
# Predicted 3374th Voxel
# Predicted 3375th Voxel
# Predicted 3376th Voxel
# Predicted 3377th Voxel
# Predicted 3378th Voxel
# Predicted 3379th Voxel
# Predicted 3380th Voxel
# Predicted 3381th Voxel
# Predicted 3382th Voxel
# Predicted 3383th Voxel
# Predicted 3384th Voxel
# Predicted 3385th Voxel
# Predicted 3386th Voxel
# Predicted 3387th Voxel
# Predicted 3388th Voxel
# Predicted 3389th Voxel
# Predicted 3390th Voxel
# Predicted 3391th Voxel
# Predicted 3392th Voxel
# Predicted 3393th Voxel
# Predicted 3394th Voxel
# Predicted 3395th Voxel
# Predicted 3396th Voxel
# Predicted 3397th Voxel
# Predicted 3398th Voxel
# Predicted 3399th Voxel
# Predicted 3400th Voxel
# Predicted 3401th Voxel
# Predicted 3402th Voxel
# Predicted 3403th Voxel
# Predicted 3404th Voxel
# Predicted 3405th Voxel
# Predicted 3406th Voxel
# Predicted 3407th Voxel
# Predicted 3408th Voxel
# Predicted 3409th Voxel
# Predicted 3410th Voxel
# Predicted 3411th Voxel
# Predicted 3412th Voxel
# Predicted 3413th Voxel
# Predicted 3414th Voxel
# Predicted 3415th Voxel
# Predicted 3416th Voxel
# Predicted 3417th Voxel
# Predicted 3418th Voxel
# Predicted 3419th Voxel
# Predicted 3420th Voxel
# Predicted 3421th Voxel
# Predicted 3422th Voxel
# Predicted 3423th Voxel
# Predicted 3424th Voxel
# Predicted 3425th Voxel
# Predicted 3426th Voxel
# Predicted 3427th Voxel
# Predicted 3428th Voxel
# Predicted 3429th Voxel
# Predicted 3430th Voxel
# Predicted 3431th Voxel
# Predicted 3432th Voxel
# Predicted 3433th Voxel
# Predicted 3434th Voxel
# Predicted 3435th Voxel
# Predicted 3436th Voxel
# Predicted 3437th Voxel
# Predicted 3438th Voxel
# Predicted 3439th Voxel
# Predicted 3440th Voxel
# Predicted 3441th Voxel
# Predicted 3442th Voxel
# Predicted 3443th Voxel
# Predicted 3444th Voxel
# Predicted 3445th Voxel
# Predicted 3446th Voxel
# Predicted 3447th Voxel
# Predicted 3448th Voxel
# Predicted 3449th Voxel
# Predicted 3450th Voxel
# Predicted 3451th Voxel
# Predicted 3452th Voxel
# Predicted 3453th Voxel
# Predicted 3454th Voxel
# Predicted 3455th Voxel
# Predicted 3456th Voxel
# Predicted 3457th Voxel
# Predicted 3458th Voxel
# Predicted 3459th Voxel
# Predicted 3460th Voxel
# Predicted 3461th Voxel
# Predicted 3462th Voxel
# Predicted 3463th Voxel
# Predicted 3464th Voxel
# Predicted 3465th Voxel
# Predicted 3466th Voxel
# Predicted 3467th Voxel
# Predicted 3468th Voxel
# Predicted 3469th Voxel
# Predicted 3470th Voxel
# Predicted 3471th Voxel
# Predicted 3472th Voxel
# Predicted 3473th Voxel
# Predicted 3474th Voxel
# Predicted 3475th Voxel
# Predicted 3476th Voxel
# Predicted 3477th Voxel
# Predicted 3478th Voxel
# Predicted 3479th Voxel
# Predicted 3480th Voxel
# Predicted 3481th Voxel
# Predicted 3482th Voxel
# Predicted 3483th Voxel
# Predicted 3484th Voxel
# Predicted 3485th Voxel
# Predicted 3486th Voxel
# Predicted 3487th Voxel
# Predicted 3488th Voxel
# Predicted 3489th Voxel
# Predicted 3490th Voxel
# Predicted 3491th Voxel
# Predicted 3492th Voxel
# Predicted 3493th Voxel
# Predicted 3494th Voxel
# Predicted 3495th Voxel
# Predicted 3496th Voxel
# Predicted 3497th Voxel
# Predicted 3498th Voxel
# Predicted 3499th Voxel
# Predicted 3500th Voxel
# Predicted 3501th Voxel
# Predicted 3502th Voxel
# Predicted 3503th Voxel
# Predicted 3504th Voxel
# Predicted 3505th Voxel
# Predicted 3506th Voxel
# Predicted 3507th Voxel
# Predicted 3508th Voxel
# Predicted 3509th Voxel
# Predicted 3510th Voxel
# Predicted 3511th Voxel
# Predicted 3512th Voxel
# Predicted 3513th Voxel
# Predicted 3514th Voxel
# Predicted 3515th Voxel
# Predicted 3516th Voxel
# Predicted 3517th Voxel
# Predicted 3518th Voxel
# Predicted 3519th Voxel
# Predicted 3520th Voxel
# Predicted 3521th Voxel
# Predicted 3522th Voxel
# Predicted 3523th Voxel
# Predicted 3524th Voxel
# Predicted 3525th Voxel
# Predicted 3526th Voxel
# Predicted 3527th Voxel
# Predicted 3528th Voxel
# Predicted 3529th Voxel
# Predicted 3530th Voxel
# Predicted 3531th Voxel
# Predicted 3532th Voxel
# Predicted 3533th Voxel
# Predicted 3534th Voxel
# Predicted 3535th Voxel
# Predicted 3536th Voxel
# Predicted 3537th Voxel
# Predicted 3538th Voxel
# Predicted 3539th Voxel
# Predicted 3540th Voxel
# Predicted 3541th Voxel
# Predicted 3542th Voxel
# Predicted 3543th Voxel
# Predicted 3544th Voxel
# Predicted 3545th Voxel
# Predicted 3546th Voxel
# Predicted 3547th Voxel
# Predicted 3548th Voxel
# Predicted 3549th Voxel
# Predicted 3550th Voxel
# Predicted 3551th Voxel
# Predicted 3552th Voxel
# Predicted 3553th Voxel
# Predicted 3554th Voxel
# Predicted 3555th Voxel
# Predicted 3556th Voxel
# Predicted 3557th Voxel
# Predicted 3558th Voxel
# Predicted 3559th Voxel
# Predicted 3560th Voxel
# Predicted 3561th Voxel
# Predicted 3562th Voxel
# Predicted 3563th Voxel
# Predicted 3564th Voxel
# Predicted 3565th Voxel
# Predicted 3566th Voxel
# Predicted 3567th Voxel
# Predicted 3568th Voxel
# Predicted 3569th Voxel
# Predicted 3570th Voxel
# Predicted 3571th Voxel
# Predicted 3572th Voxel
# Predicted 3573th Voxel
# Predicted 3574th Voxel
# Predicted 3575th Voxel
# Predicted 3576th Voxel
# Predicted 3577th Voxel
# Predicted 3578th Voxel
# Predicted 3579th Voxel
# Predicted 3580th Voxel
# Predicted 3581th Voxel
# Predicted 3582th Voxel
# Predicted 3583th Voxel
# Predicted 3584th Voxel
# Predicted 3585th Voxel
# Predicted 3586th Voxel
# Predicted 3587th Voxel
# Predicted 3588th Voxel
# Predicted 3589th Voxel
# Predicted 3590th Voxel
# Predicted 3591th Voxel
# Predicted 3592th Voxel
# Predicted 3593th Voxel
# Predicted 3594th Voxel
# Predicted 3595th Voxel
# Predicted 3596th Voxel
# Predicted 3597th Voxel
# Predicted 3598th Voxel
# Predicted 3599th Voxel
# Predicted 3600th Voxel
# Predicted 3601th Voxel
# Predicted 3602th Voxel
# Predicted 3603th Voxel
# Predicted 3604th Voxel
# Predicted 3605th Voxel
# Predicted 3606th Voxel
# Predicted 3607th Voxel
# Predicted 3608th Voxel
# Predicted 3609th Voxel
# Predicted 3610th Voxel
# Predicted 3611th Voxel
# Predicted 3612th Voxel
# Predicted 3613th Voxel
# Predicted 3614th Voxel
# Predicted 3615th Voxel
# Predicted 3616th Voxel
# Predicted 3617th Voxel
# Predicted 3618th Voxel
# Predicted 3619th Voxel
# Predicted 3620th Voxel
# Predicted 3621th Voxel
# Predicted 3622th Voxel
# Predicted 3623th Voxel
# Predicted 3624th Voxel
# Predicted 3625th Voxel
# Predicted 3626th Voxel
# Predicted 3627th Voxel
# Predicted 3628th Voxel
# Predicted 3629th Voxel
# Predicted 3630th Voxel
# Predicted 3631th Voxel
# Predicted 3632th Voxel
# Predicted 3633th Voxel
# Predicted 3634th Voxel
# Predicted 3635th Voxel
# Predicted 3636th Voxel
# Predicted 3637th Voxel
# Predicted 3638th Voxel
# Predicted 3639th Voxel
# Predicted 3640th Voxel
# Predicted 3641th Voxel
# Predicted 3642th Voxel
# Predicted 3643th Voxel
# Predicted 3644th Voxel
# Predicted 3645th Voxel
# Predicted 3646th Voxel
# Predicted 3647th Voxel
# Predicted 3648th Voxel
# Predicted 3649th Voxel
# Predicted 3650th Voxel
# Predicted 3651th Voxel
# Predicted 3652th Voxel
# Predicted 3653th Voxel
# Predicted 3654th Voxel
# Predicted 3655th Voxel
# Predicted 3656th Voxel
# Predicted 3657th Voxel
# Predicted 3658th Voxel
# Predicted 3659th Voxel
# Predicted 3660th Voxel
# Predicted 3661th Voxel
# Predicted 3662th Voxel
# Predicted 3663th Voxel
# Predicted 3664th Voxel
# Predicted 3665th Voxel
# Predicted 3666th Voxel
# Predicted 3667th Voxel
# Predicted 3668th Voxel
# Predicted 3669th Voxel
# Predicted 3670th Voxel
# Predicted 3671th Voxel
# Predicted 3672th Voxel
# Predicted 3673th Voxel
# Predicted 3674th Voxel
# Predicted 3675th Voxel
# Predicted 3676th Voxel
# Predicted 3677th Voxel
# Predicted 3678th Voxel
# Predicted 3679th Voxel
# Predicted 3680th Voxel
# Predicted 3681th Voxel
# Predicted 3682th Voxel
# Predicted 3683th Voxel
# Predicted 3684th Voxel
# Predicted 3685th Voxel
# Predicted 3686th Voxel
# Predicted 3687th Voxel
# Predicted 3688th Voxel
# Predicted 3689th Voxel
# Predicted 3690th Voxel
# Predicted 3691th Voxel
# Predicted 3692th Voxel
# Predicted 3693th Voxel
# Predicted 3694th Voxel
# Predicted 3695th Voxel
# Predicted 3696th Voxel
# Predicted 3697th Voxel
# Predicted 3698th Voxel
# Predicted 3699th Voxel
# Predicted 3700th Voxel
# Predicted 3701th Voxel
# Predicted 3702th Voxel
# Predicted 3703th Voxel
# Predicted 3704th Voxel
# Predicted 3705th Voxel
# Predicted 3706th Voxel
# Predicted 3707th Voxel
# Predicted 3708th Voxel
# Predicted 3709th Voxel
# Predicted 3710th Voxel
# Predicted 3711th Voxel
# Predicted 3712th Voxel
# Predicted 3713th Voxel
# Predicted 3714th Voxel
# Predicted 3715th Voxel
# Predicted 3716th Voxel
# Predicted 3717th Voxel
# Predicted 3718th Voxel
# Predicted 3719th Voxel
# Predicted 3720th Voxel
# Predicted 3721th Voxel
# Predicted 3722th Voxel
# Predicted 3723th Voxel
# Predicted 3724th Voxel
# Predicted 3725th Voxel
# Predicted 3726th Voxel
# Predicted 3727th Voxel
# Predicted 3728th Voxel
# Predicted 3729th Voxel
# Predicted 3730th Voxel
# Predicted 3731th Voxel
# Predicted 3732th Voxel
# Predicted 3733th Voxel
# Predicted 3734th Voxel
# Predicted 3735th Voxel
# Predicted 3736th Voxel
# Predicted 3737th Voxel
# Predicted 3738th Voxel
# Predicted 3739th Voxel
# Predicted 3740th Voxel
# Predicted 3741th Voxel
# Predicted 3742th Voxel
# Predicted 3743th Voxel
# Predicted 3744th Voxel
# Predicted 3745th Voxel
# Predicted 3746th Voxel
# Predicted 3747th Voxel
# Predicted 3748th Voxel
# Predicted 3749th Voxel
# Predicted 3750th Voxel
# Predicted 3751th Voxel
# Predicted 3752th Voxel
# Predicted 3753th Voxel
# Predicted 3754th Voxel
# Predicted 3755th Voxel
# Predicted 3756th Voxel
# Predicted 3757th Voxel
# Predicted 3758th Voxel
# Predicted 3759th Voxel
# Predicted 3760th Voxel
# Predicted 3761th Voxel
# Predicted 3762th Voxel
# Predicted 3763th Voxel
# Predicted 3764th Voxel
# Predicted 3765th Voxel
# Predicted 3766th Voxel
# Predicted 3767th Voxel
# Predicted 3768th Voxel
# Inference complete. Voxels saved to output_voxel.npy, partial_voxel.npy, complete_voxel.npy.

# %% [markdown]
# # Voxels Given to Model: The missing Voxels

# %%
def inference_missing_voxels(model_path, test_samples, device):
    """
    Perform inference only on voxels that are missing from the complete object (i.e., (partial == 0) & (complete == 1)).
    Sorts these voxels by density in 3x3x3 window (filled neighbors), breaking ties by distance to origin.
    """
    print(f"Using device: {device}")
    sample_idx = random.randint(0, len(test_samples)-1)
    # sample_idx = 5
    complete, partial = test_samples[sample_idx]
    print(f"Selected sample index: {sample_idx}")


    # model = IterativeVoxelModel(
    #     d_model=96,
    #     num_heads=6,
    #     num_layers=3,
    #     max_grid_size=32,
    #     window_size=3,
    #     dropout=0.1
    # ).to(device)

    model = IterativeVoxelModel(
        d_model=48,
        num_heads=4,
        num_layers=3,
        max_grid_size=16,
        window_size=5,
        dropout=0.1
    ).to(device)


    checkpoint = torch.load(model_path, map_location=device)
    state_dict = checkpoint['model_state_dict']
    from collections import OrderedDict
    new_state_dict = OrderedDict()
    for k, v in state_dict.items():
        new_key = k.replace('module.', '') if k.startswith('module.') else k
        new_state_dict[new_key] = v
    model.load_state_dict(new_state_dict)
    model.eval()
    partial_tensor = partial.unsqueeze(0).unsqueeze(0).to(device)  # [1,1,D,H,W]
    known_mask = (partial_tensor > 0).float()
    complete_tensor = complete.unsqueeze(0).unsqueeze(0).to(device)
    D, H, W = partial.shape
    window = model.window_size
    # Find missing voxels: present in complete, missing in partial
    missing_voxels = torch.nonzero((partial_tensor[0,0] == 0) & (complete_tensor[0,0] == 1), as_tuple=False)  # [N,3]
    # Sort missing voxels by density in 3x3x3 window, break ties by distance to origin
    def count_filled_neighbors_3x3x3(x, y, z, grid):
        count = 0
        for dx in [-1, 0, 1]:
            for dy in [-1, 0, 1]:
                for dz in [-1, 0, 1]:
                    nx, ny, nz = x + dx, y + dy, z + dz
                    if 0 <= nx < D and 0 <= ny < H and 0 <= nz < W:
                        if dx == 0 and dy == 0 and dz == 0:
                            continue
                        if grid[0,0,nx,ny,nz] > 0:
                            count += 1
        return count
    voxel_scores = []
    for v in missing_voxels:
        x, y, z = v.tolist()
        density = count_filled_neighbors_3x3x3(x, y, z, partial_tensor)
        dist = x**2 + y**2 + z**2
        voxel_scores.append((x, y, z, density, dist))
    voxel_scores.sort(key=lambda x: (-x[3], x[4]))
    sorted_missing_voxels = [(x, y, z) for x, y, z, _, _ in voxel_scores]
    print("Entering prediction for missing voxels...")
    with torch.no_grad():
        i = 0
        for x, y, z in sorted_missing_voxels:
            patch, mask_patch = neighborhood_raw(partial_tensor, 0, x, y, z, window)
            logits = model(patch.to(device), mask_patch.to(device))
            prob = torch.sigmoid(logits).squeeze().item()
            pred_filled = 1.0 if prob > 0.5 else 0.0
            partial_tensor[0,0,x,y,z] = pred_filled
            known_mask[0,0,x,y,z] = 1.0
            print(f"Predicted {i}th missing voxel")
            i += 1
    output_voxels = partial_tensor.squeeze().cpu().numpy()
    np.save("output_voxel.npy", output_voxels)
    np.save("partial_voxel.npy", partial.numpy())
    np.save("complete_voxel.npy", complete.numpy())
    print("Inference complete. Voxels saved to output_voxel.npy, partial_voxel.npy, complete_voxel.npy.")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
inference_missing_voxels(MODEL_SAVE_PATH, test_samples, device=device)
# Out:
# Using device: cuda
# Selected sample index: 373
# Entering prediction for missing voxels...
# Predicted 0th missing voxel
# Predicted 1th missing voxel
# Predicted 2th missing voxel
# Predicted 3th missing voxel
# Predicted 4th missing voxel
# Inference complete. Voxels saved to output_voxel.npy, partial_voxel.npy, complete_voxel.npy.

# %% [markdown]
# # Voxels given to Model: 50% of the voxels are all truly missing and 50% are randomly empty and irrelevant voxels

# %%
def inference_balanced_missing_empty(model_path, test_samples, device):
    """
    Perform inference on a balanced set of voxels:
    - Half are missing voxels (present in complete, missing in partial)
    - Half are truly empty voxels (empty in both complete and partial), randomly sampled to match the number of missing voxels
    Voxels are sorted by filled neighbor density (3x3x3 window), breaking ties by distance to origin.
    Additionally, save an npy file ('test.npy') where all truly missing voxels are set to filled (1).
    """
    print(f"Using device: {device}")
    sample_idx = random.randint(0, len(test_samples)-1)
    # sample_idx = 5
    complete, partial = test_samples[sample_idx]
    print(f"Selected sample index: {sample_idx}")

    # model = IterativeVoxelModel(
    #     d_model=96,
    #     num_heads=6,
    #     num_layers=3,
    #     max_grid_size=32,
    #     window_size=3,
    #     dropout=0.1
    # ).to(device)

    model = IterativeVoxelModel(
        d_model=48,
        num_heads=4,
        num_layers=3,
        max_grid_size=16,
        window_size=5,
        dropout=0.1
    ).to(device)

    checkpoint = torch.load(model_path, map_location=device)
    state_dict = checkpoint['model_state_dict']
    from collections import OrderedDict
    new_state_dict = OrderedDict()
    for k, v in state_dict.items():
        new_key = k.replace('module.', '') if k.startswith('module.') else k
        new_state_dict[new_key] = v
    model.load_state_dict(new_state_dict)
    model.eval()
    partial_tensor = partial.unsqueeze(0).unsqueeze(0).to(device)  # [1,1,D,H,W]
    known_mask = (partial_tensor > 0).float()
    complete_tensor = complete.unsqueeze(0).unsqueeze(0).to(device)
    D, H, W = partial.shape
    window = model.window_size
    # Find missing voxels: present in complete, missing in partial
    missing_voxels = torch.nonzero((partial_tensor[0,0] == 0) & (complete_tensor[0,0] == 1), as_tuple=False)  # [N,3]
    num_missing = missing_voxels.shape[0]
    # Find truly empty voxels: empty in both complete and partial
    truly_empty_voxels = torch.nonzero((partial_tensor[0,0] == 0) & (complete_tensor[0,0] == 0), as_tuple=False)  # [M,3]
    # Randomly sample truly empty voxels to match number of missing voxels
    if num_missing > 0 and truly_empty_voxels.shape[0] > 0:
        FACTOR = 3
        perm = torch.randperm(truly_empty_voxels.shape[0])[:num_missing*FACTOR]
        sampled_empty_voxels = truly_empty_voxels[perm]
    else:
        sampled_empty_voxels = torch.empty((0,3), dtype=torch.long)
    # Combine both sets
    candidate_voxels = torch.cat([missing_voxels, sampled_empty_voxels], dim=0)
    # Sort candidates by density and distance to origin
    def count_filled_neighbors_3x3x3(x, y, z, grid):
        count = 0
        for dx in [-1, 0, 1]:
            for dy in [-1, 0, 1]:
                for dz in [-1, 0, 1]:
                    nx, ny, nz = x + dx, y + dy, z + dz
                    if 0 <= nx < D and 0 <= ny < H and 0 <= nz < W:
                        if dx == 0 and dy == 0 and dz == 0:
                            continue
                        if grid[0,0,nx,ny,nz] > 0:
                            count += 1
        return count
    voxel_scores = []
    for v in candidate_voxels:
        x, y, z = v.tolist()
        density = count_filled_neighbors_3x3x3(x, y, z, partial_tensor)
        dist = x**2 + y**2 + z**2
        voxel_scores.append((x, y, z, density, dist))
    voxel_scores.sort(key=lambda x: (-x[3], x[4]))
    sorted_voxels = [(x, y, z) for x, y, z, _, _ in voxel_scores]
    print(f"Entering prediction for {len(sorted_voxels)} balanced voxels...")
    with torch.no_grad():
        i = 0
        for x, y, z in sorted_voxels:
            patch, mask_patch = neighborhood_raw(partial_tensor, 0, x, y, z, window)
            logits = model(patch.to(device), mask_patch.to(device))
            prob = torch.sigmoid(logits).squeeze().item()
            pred_filled = 1.0 if prob > 0.9 else 0.0
            partial_tensor[0,0,x,y,z] = pred_filled
            known_mask[0,0,x,y,z] = 1.0
            print(f"Predicted {i}th balanced voxel")
            i += 1
    output_voxels = partial_tensor.squeeze().cpu().numpy()
    np.save("output_voxel.npy", output_voxels)
    np.save("partial_voxel.npy", partial.numpy())
    np.save("complete_voxel.npy", complete.numpy())
    print("Inference complete. Voxels saved to output_voxel.npy, partial_voxel.npy, complete_voxel.npy.")

    # --- Save test.npy with all truly missing voxels set to filled (1) ---
    test_voxel = partial.clone()
    for v in sampled_empty_voxels:
        x, y, z = v.tolist()
        test_voxel[x, y, z] = 1.0
    np.save("test.npy", test_voxel.cpu().numpy())
    print("test.npy saved: all truly missing voxels set to filled.")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
inference_balanced_missing_empty(MODEL_SAVE_PATH, test_samples, device=device)
# Out:
# Using device: cuda
# Selected sample index: 823
# Entering prediction for 52 balanced voxels...
# Predicted 0th balanced voxel
# Predicted 1th balanced voxel
# Predicted 2th balanced voxel
# Predicted 3th balanced voxel
# Predicted 4th balanced voxel
# Predicted 5th balanced voxel
# Predicted 6th balanced voxel
# Predicted 7th balanced voxel
# Predicted 8th balanced voxel
# Predicted 9th balanced voxel
# Predicted 10th balanced voxel
# Predicted 11th balanced voxel
# Predicted 12th balanced voxel
# Predicted 13th balanced voxel
# Predicted 14th balanced voxel
# Predicted 15th balanced voxel
# Predicted 16th balanced voxel
# Predicted 17th balanced voxel
# Predicted 18th balanced voxel
# Predicted 19th balanced voxel
# Predicted 20th balanced voxel
# Predicted 21th balanced voxel
# Predicted 22th balanced voxel
# Predicted 23th balanced voxel
# Predicted 24th balanced voxel
# Predicted 25th balanced voxel
# Predicted 26th balanced voxel
# Predicted 27th balanced voxel
# Predicted 28th balanced voxel
# Predicted 29th balanced voxel
# Predicted 30th balanced voxel
# Predicted 31th balanced voxel
# Predicted 32th balanced voxel
# Predicted 33th balanced voxel
# Predicted 34th balanced voxel
# Predicted 35th balanced voxel
# Predicted 36th balanced voxel
# Predicted 37th balanced voxel
# Predicted 38th balanced voxel
# Predicted 39th balanced voxel
# Predicted 40th balanced voxel
# Predicted 41th balanced voxel
# Predicted 42th balanced voxel
# Predicted 43th balanced voxel
# Predicted 44th balanced voxel
# Predicted 45th balanced voxel
# Predicted 46th balanced voxel
# Predicted 47th balanced voxel
# Predicted 48th balanced voxel
# Predicted 49th balanced voxel
# Predicted 50th balanced voxel
# Predicted 51th balanced voxel
# Inference complete. Voxels saved to output_voxel.npy, partial_voxel.npy, complete_voxel.npy.
# test.npy saved: all truly missing voxels set to filled.

# %%
def inference_balanced_missing_empty_compact(model_path, test_samples, device):
    """
    Perform inference on a balanced set of voxels:
    - Half are missing voxels (present in complete, missing in partial)
    - Half are truly empty voxels (empty in both complete and partial), sampled to be close to the object (high filled neighbor density)
    Voxels are sorted by filled neighbor density (3x3x3 window), breaking ties by distance to origin.
    Additionally, save an npy file ('test.npy') where all truly missing voxels are set to filled (1).
    """
    print(f"Using device: {device}")
    sample_idx = random.randint(0, len(test_samples)-1)
    # sample_idx = 5
    complete, partial = test_samples[sample_idx]
    print(f"Selected sample index: {sample_idx}")

    # model = IterativeVoxelModel(
    #     d_model=96,
    #     num_heads=6,
    #     num_layers=3,
    #     max_grid_size=32,
    #     window_size=3,
    #     dropout=0.1
    # ).to(device)

    model = IterativeVoxelModel(
        d_model=48,
        num_heads=4,
        num_layers=3,
        max_grid_size=16,
        window_size=5,
        dropout=0.1
    ).to(device)

    checkpoint = torch.load(model_path, map_location=device)
    state_dict = checkpoint['model_state_dict']
    from collections import OrderedDict
    new_state_dict = OrderedDict()
    for k, v in state_dict.items():
        new_key = k.replace('module.', '') if k.startswith('module.') else k
        new_state_dict[new_key] = v
    model.load_state_dict(new_state_dict)
    model.eval()
    partial_tensor = partial.unsqueeze(0).unsqueeze(0).to(device)  # [1,1,D,H,W]
    known_mask = (partial_tensor > 0).float()
    complete_tensor = complete.unsqueeze(0).unsqueeze(0).to(device)
    D, H, W = partial.shape
    window = model.window_size
    # Find missing voxels: present in complete, missing in partial
    missing_voxels = torch.nonzero((partial_tensor[0,0] == 0) & (complete_tensor[0,0] == 1), as_tuple=False).to(device)  # [N,3]
    num_missing = missing_voxels.shape[0]
    # Find truly empty voxels: empty in both complete and partial
    truly_empty_voxels = torch.nonzero((partial_tensor[0,0] == 0) & (complete_tensor[0,0] == 0), as_tuple=False).to(device)  # [M,3]
    # --- Sample truly empty voxels to be close to the object (high filled neighbor density) ---
    def count_filled_neighbors_3x3x3(x, y, z, grid):
        count = 0
        for dx in [-1, 0, 1]:
            for dy in [-1, 0, 1]:
                for dz in [-1, 0, 1]:
                    nx, ny, nz = x + dx, y + dy, z + dz
                    if 0 <= nx < D and 0 <= ny < H and 0 <= nz < W:
                        if dx == 0 and dy == 0 and dz == 0:
                            continue
                        if grid[0,0,nx,ny,nz] > 0:
                            count += 1
        return count
    # Score truly empty voxels by density and distance
    empty_scores = []
    for v in truly_empty_voxels:
        x, y, z = v.tolist()
        density = count_filled_neighbors_3x3x3(x, y, z, partial_tensor)
        dist = x**2 + y**2 + z**2
        empty_scores.append((x, y, z, density, dist))
    # Sort by high density, then close to origin
    empty_scores.sort(key=lambda x: (-x[3], x[4]))
    # Take top num_missing*FACTOR voxels
    FACTOR = 8
    sampled_empty_voxels = torch.tensor([s[:3] for s in empty_scores[:num_missing*FACTOR]], dtype=torch.long, device=device) if num_missing > 0 and len(empty_scores) > 0 else torch.empty((0,3), dtype=torch.long, device=device)
    # Ensure both tensors are on the same device before concatenation
    missing_voxels = missing_voxels.to(device)
    sampled_empty_voxels = sampled_empty_voxels.to(device)
    candidate_voxels = torch.cat([missing_voxels, sampled_empty_voxels], dim=0)
    # Sort candidates by density and distance to origin
    voxel_scores = []
    for v in candidate_voxels:
        x, y, z = v.tolist()
        density = count_filled_neighbors_3x3x3(x, y, z, partial_tensor)
        dist = x**2 + y**2 + z**2
        voxel_scores.append((x, y, z, density, dist))
    voxel_scores.sort(key=lambda x: (-x[3], x[4]))
    sorted_voxels = [(x, y, z) for x, y, z, _, _ in voxel_scores]
    print(f"Entering prediction for {len(sorted_voxels)} balanced voxels...")
    with torch.no_grad():
        i = 0
        for x, y, z in sorted_voxels:
            patch, mask_patch = neighborhood_raw(partial_tensor, 0, x, y, z, window)
            logits = model(patch.to(device), mask_patch.to(device))
            prob = torch.sigmoid(logits).squeeze().item()
            pred_filled = 1.0 if prob > 0.9 else 0.0
            partial_tensor[0,0,x,y,z] = pred_filled
            known_mask[0,0,x,y,z] = 1.0
            print(f"Predicted {i}th balanced voxel")
            i += 1
    output_voxels = partial_tensor.squeeze().cpu().numpy()
    np.save("output_voxel.npy", output_voxels)
    np.save("partial_voxel.npy", partial.numpy())
    np.save("complete_voxel.npy", complete.numpy())
    print("Inference complete. Voxels saved to output_voxel.npy, partial_voxel.npy, complete_voxel.npy.")

    # --- Save test.npy with all sampled truly empty voxels set to filled (1) ---
    test_voxel = partial.clone()
    for v in sampled_empty_voxels:
        x, y, z = v.tolist()
        test_voxel[x, y, z] = 1.0
    np.save("test.npy", test_voxel.cpu().numpy())
    print("test.npy saved: all sampled truly empty voxels set to filled.")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
inference_balanced_missing_empty_compact(MODEL_SAVE_PATH, test_samples, device=device)
# Out:
# Using device: cuda
# Selected sample index: 986
# Entering prediction for 935 balanced voxels...
# Predicted 0th balanced voxel
# Predicted 1th balanced voxel
# Predicted 2th balanced voxel
# Predicted 3th balanced voxel
# Predicted 4th balanced voxel
# Predicted 5th balanced voxel
# Predicted 6th balanced voxel
# Predicted 7th balanced voxel
# Predicted 8th balanced voxel
# Predicted 9th balanced voxel
# Predicted 10th balanced voxel
# Predicted 11th balanced voxel
# Predicted 12th balanced voxel
# Predicted 13th balanced voxel
# Predicted 14th balanced voxel
# Predicted 15th balanced voxel
# Predicted 16th balanced voxel
# Predicted 17th balanced voxel
# Predicted 18th balanced voxel
# Predicted 19th balanced voxel
# Predicted 20th balanced voxel
# Predicted 21th balanced voxel
# Predicted 22th balanced voxel
# Predicted 23th balanced voxel
# Predicted 24th balanced voxel
# Predicted 25th balanced voxel
# Predicted 26th balanced voxel
# Predicted 27th balanced voxel
# Predicted 28th balanced voxel
# Predicted 29th balanced voxel
# Predicted 30th balanced voxel
# Predicted 31th balanced voxel
# Predicted 32th balanced voxel
# Predicted 33th balanced voxel
# Predicted 34th balanced voxel
# Predicted 35th balanced voxel
# Predicted 36th balanced voxel
# Predicted 37th balanced voxel
# Predicted 38th balanced voxel
# Predicted 39th balanced voxel
# Predicted 40th balanced voxel
# Predicted 41th balanced voxel
# Predicted 42th balanced voxel
# Predicted 43th balanced voxel
# Predicted 44th balanced voxel
# Predicted 45th balanced voxel
# Predicted 46th balanced voxel
# Predicted 47th balanced voxel
# Predicted 48th balanced voxel
# Predicted 49th balanced voxel
# Predicted 50th balanced voxel
# Predicted 51th balanced voxel
# Predicted 52th balanced voxel
# Predicted 53th balanced voxel
# Predicted 54th balanced voxel
# Predicted 55th balanced voxel
# Predicted 56th balanced voxel
# Predicted 57th balanced voxel
# Predicted 58th balanced voxel
# Predicted 59th balanced voxel
# Predicted 60th balanced voxel
# Predicted 61th balanced voxel
# Predicted 62th balanced voxel
# Predicted 63th balanced voxel
# Predicted 64th balanced voxel
# Predicted 65th balanced voxel
# Predicted 66th balanced voxel
# Predicted 67th balanced voxel
# Predicted 68th balanced voxel
# Predicted 69th balanced voxel
# Predicted 70th balanced voxel
# Predicted 71th balanced voxel
# Predicted 72th balanced voxel
# Predicted 73th balanced voxel
# Predicted 74th balanced voxel
# Predicted 75th balanced voxel
# Predicted 76th balanced voxel
# Predicted 77th balanced voxel
# Predicted 78th balanced voxel
# Predicted 79th balanced voxel
# Predicted 80th balanced voxel
# Predicted 81th balanced voxel
# Predicted 82th balanced voxel
# Predicted 83th balanced voxel
# Predicted 84th balanced voxel
# Predicted 85th balanced voxel
# Predicted 86th balanced voxel
# Predicted 87th balanced voxel
# Predicted 88th balanced voxel
# Predicted 89th balanced voxel
# Predicted 90th balanced voxel
# Predicted 91th balanced voxel
# Predicted 92th balanced voxel
# Predicted 93th balanced voxel
# Predicted 94th balanced voxel
# Predicted 95th balanced voxel
# Predicted 96th balanced voxel
# Predicted 97th balanced voxel
# Predicted 98th balanced voxel
# Predicted 99th balanced voxel
# Predicted 100th balanced voxel
# Predicted 101th balanced voxel
# Predicted 102th balanced voxel
# Predicted 103th balanced voxel
# Predicted 104th balanced voxel
# Predicted 105th balanced voxel
# Predicted 106th balanced voxel
# Predicted 107th balanced voxel
# Predicted 108th balanced voxel
# Predicted 109th balanced voxel
# Predicted 110th balanced voxel
# Predicted 111th balanced voxel
# Predicted 112th balanced voxel
# Predicted 113th balanced voxel
# Predicted 114th balanced voxel
# Predicted 115th balanced voxel
# Predicted 116th balanced voxel
# Predicted 117th balanced voxel
# Predicted 118th balanced voxel
# Predicted 119th balanced voxel
# Predicted 120th balanced voxel
# Predicted 121th balanced voxel
# Predicted 122th balanced voxel
# Predicted 123th balanced voxel
# Predicted 124th balanced voxel
# Predicted 125th balanced voxel
# Predicted 126th balanced voxel
# Predicted 127th balanced voxel
# Predicted 128th balanced voxel
# Predicted 129th balanced voxel
# Predicted 130th balanced voxel
# Predicted 131th balanced voxel
# Predicted 132th balanced voxel
# Predicted 133th balanced voxel
# Predicted 134th balanced voxel
# Predicted 135th balanced voxel
# Predicted 136th balanced voxel
# Predicted 137th balanced voxel
# Predicted 138th balanced voxel
# Predicted 139th balanced voxel
# Predicted 140th balanced voxel
# Predicted 141th balanced voxel
# Predicted 142th balanced voxel
# Predicted 143th balanced voxel
# Predicted 144th balanced voxel
# Predicted 145th balanced voxel
# Predicted 146th balanced voxel
# Predicted 147th balanced voxel
# Predicted 148th balanced voxel
# Predicted 149th balanced voxel
# Predicted 150th balanced voxel
# Predicted 151th balanced voxel
# Predicted 152th balanced voxel
# Predicted 153th balanced voxel
# Predicted 154th balanced voxel
# Predicted 155th balanced voxel
# Predicted 156th balanced voxel
# Predicted 157th balanced voxel
# Predicted 158th balanced voxel
# Predicted 159th balanced voxel
# Predicted 160th balanced voxel
# Predicted 161th balanced voxel
# Predicted 162th balanced voxel
# Predicted 163th balanced voxel
# Predicted 164th balanced voxel
# Predicted 165th balanced voxel
# Predicted 166th balanced voxel
# Predicted 167th balanced voxel
# Predicted 168th balanced voxel
# Predicted 169th balanced voxel
# Predicted 170th balanced voxel
# Predicted 171th balanced voxel
# Predicted 172th balanced voxel
# Predicted 173th balanced voxel
# Predicted 174th balanced voxel
# Predicted 175th balanced voxel
# Predicted 176th balanced voxel
# Predicted 177th balanced voxel
# Predicted 178th balanced voxel
# Predicted 179th balanced voxel
# Predicted 180th balanced voxel
# Predicted 181th balanced voxel
# Predicted 182th balanced voxel
# Predicted 183th balanced voxel
# Predicted 184th balanced voxel
# Predicted 185th balanced voxel
# Predicted 186th balanced voxel
# Predicted 187th balanced voxel
# Predicted 188th balanced voxel
# Predicted 189th balanced voxel
# Predicted 190th balanced voxel
# Predicted 191th balanced voxel
# Predicted 192th balanced voxel
# Predicted 193th balanced voxel
# Predicted 194th balanced voxel
# Predicted 195th balanced voxel
# Predicted 196th balanced voxel
# Predicted 197th balanced voxel
# Predicted 198th balanced voxel
# Predicted 199th balanced voxel
# Predicted 200th balanced voxel
# Predicted 201th balanced voxel
# Predicted 202th balanced voxel
# Predicted 203th balanced voxel
# Predicted 204th balanced voxel
# Predicted 205th balanced voxel
# Predicted 206th balanced voxel
# Predicted 207th balanced voxel
# Predicted 208th balanced voxel
# Predicted 209th balanced voxel
# Predicted 210th balanced voxel
# Predicted 211th balanced voxel
# Predicted 212th balanced voxel
# Predicted 213th balanced voxel
# Predicted 214th balanced voxel
# Predicted 215th balanced voxel
# Predicted 216th balanced voxel
# Predicted 217th balanced voxel
# Predicted 218th balanced voxel
# Predicted 219th balanced voxel
# Predicted 220th balanced voxel
# Predicted 221th balanced voxel
# Predicted 222th balanced voxel
# Predicted 223th balanced voxel
# Predicted 224th balanced voxel
# Predicted 225th balanced voxel
# Predicted 226th balanced voxel
# Predicted 227th balanced voxel
# Predicted 228th balanced voxel
# Predicted 229th balanced voxel
# Predicted 230th balanced voxel
# Predicted 231th balanced voxel
# Predicted 232th balanced voxel
# Predicted 233th balanced voxel
# Predicted 234th balanced voxel
# Predicted 235th balanced voxel
# Predicted 236th balanced voxel
# Predicted 237th balanced voxel
# Predicted 238th balanced voxel
# Predicted 239th balanced voxel
# Predicted 240th balanced voxel
# Predicted 241th balanced voxel
# Predicted 242th balanced voxel
# Predicted 243th balanced voxel
# Predicted 244th balanced voxel
# Predicted 245th balanced voxel
# Predicted 246th balanced voxel
# Predicted 247th balanced voxel
# Predicted 248th balanced voxel
# Predicted 249th balanced voxel
# Predicted 250th balanced voxel
# Predicted 251th balanced voxel
# Predicted 252th balanced voxel
# Predicted 253th balanced voxel
# Predicted 254th balanced voxel
# Predicted 255th balanced voxel
# Predicted 256th balanced voxel
# Predicted 257th balanced voxel
# Predicted 258th balanced voxel
# Predicted 259th balanced voxel
# Predicted 260th balanced voxel
# Predicted 261th balanced voxel
# Predicted 262th balanced voxel
# Predicted 263th balanced voxel
# Predicted 264th balanced voxel
# Predicted 265th balanced voxel
# Predicted 266th balanced voxel
# Predicted 267th balanced voxel
# Predicted 268th balanced voxel
# Predicted 269th balanced voxel
# Predicted 270th balanced voxel
# Predicted 271th balanced voxel
# Predicted 272th balanced voxel
# Predicted 273th balanced voxel
# Predicted 274th balanced voxel
# Predicted 275th balanced voxel
# Predicted 276th balanced voxel
# Predicted 277th balanced voxel
# Predicted 278th balanced voxel
# Predicted 279th balanced voxel
# Predicted 280th balanced voxel
# Predicted 281th balanced voxel
# Predicted 282th balanced voxel
# Predicted 283th balanced voxel
# Predicted 284th balanced voxel
# Predicted 285th balanced voxel
# Predicted 286th balanced voxel
# Predicted 287th balanced voxel
# Predicted 288th balanced voxel
# Predicted 289th balanced voxel
# Predicted 290th balanced voxel
# Predicted 291th balanced voxel
# Predicted 292th balanced voxel
# Predicted 293th balanced voxel
# Predicted 294th balanced voxel
# Predicted 295th balanced voxel
# Predicted 296th balanced voxel
# Predicted 297th balanced voxel
# Predicted 298th balanced voxel
# Predicted 299th balanced voxel
# Predicted 300th balanced voxel
# Predicted 301th balanced voxel
# Predicted 302th balanced voxel
# Predicted 303th balanced voxel
# Predicted 304th balanced voxel
# Predicted 305th balanced voxel
# Predicted 306th balanced voxel
# Predicted 307th balanced voxel
# Predicted 308th balanced voxel
# Predicted 309th balanced voxel
# Predicted 310th balanced voxel
# Predicted 311th balanced voxel
# Predicted 312th balanced voxel
# Predicted 313th balanced voxel
# Predicted 314th balanced voxel
# Predicted 315th balanced voxel
# Predicted 316th balanced voxel
# Predicted 317th balanced voxel
# Predicted 318th balanced voxel
# Predicted 319th balanced voxel
# Predicted 320th balanced voxel
# Predicted 321th balanced voxel
# Predicted 322th balanced voxel
# Predicted 323th balanced voxel
# Predicted 324th balanced voxel
# Predicted 325th balanced voxel
# Predicted 326th balanced voxel
# Predicted 327th balanced voxel
# Predicted 328th balanced voxel
# Predicted 329th balanced voxel
# Predicted 330th balanced voxel
# Predicted 331th balanced voxel
# Predicted 332th balanced voxel
# Predicted 333th balanced voxel
# Predicted 334th balanced voxel
# Predicted 335th balanced voxel
# Predicted 336th balanced voxel
# Predicted 337th balanced voxel
# Predicted 338th balanced voxel
# Predicted 339th balanced voxel
# Predicted 340th balanced voxel
# Predicted 341th balanced voxel
# Predicted 342th balanced voxel
# Predicted 343th balanced voxel
# Predicted 344th balanced voxel
# Predicted 345th balanced voxel
# Predicted 346th balanced voxel
# Predicted 347th balanced voxel
# Predicted 348th balanced voxel
# Predicted 349th balanced voxel
# Predicted 350th balanced voxel
# Predicted 351th balanced voxel
# Predicted 352th balanced voxel
# Predicted 353th balanced voxel
# Predicted 354th balanced voxel
# Predicted 355th balanced voxel
# Predicted 356th balanced voxel
# Predicted 357th balanced voxel
# Predicted 358th balanced voxel
# Predicted 359th balanced voxel
# Predicted 360th balanced voxel
# Predicted 361th balanced voxel
# Predicted 362th balanced voxel
# Predicted 363th balanced voxel
# Predicted 364th balanced voxel
# Predicted 365th balanced voxel
# Predicted 366th balanced voxel
# Predicted 367th balanced voxel
# Predicted 368th balanced voxel
# Predicted 369th balanced voxel
# Predicted 370th balanced voxel
# Predicted 371th balanced voxel
# Predicted 372th balanced voxel
# Predicted 373th balanced voxel
# Predicted 374th balanced voxel
# Predicted 375th balanced voxel
# Predicted 376th balanced voxel
# Predicted 377th balanced voxel
# Predicted 378th balanced voxel
# Predicted 379th balanced voxel
# Predicted 380th balanced voxel
# Predicted 381th balanced voxel
# Predicted 382th balanced voxel
# Predicted 383th balanced voxel
# Predicted 384th balanced voxel
# Predicted 385th balanced voxel
# Predicted 386th balanced voxel
# Predicted 387th balanced voxel
# Predicted 388th balanced voxel
# Predicted 389th balanced voxel
# Predicted 390th balanced voxel
# Predicted 391th balanced voxel
# Predicted 392th balanced voxel
# Predicted 393th balanced voxel
# Predicted 394th balanced voxel
# Predicted 395th balanced voxel
# Predicted 396th balanced voxel
# Predicted 397th balanced voxel
# Predicted 398th balanced voxel
# Predicted 399th balanced voxel
# Predicted 400th balanced voxel
# Predicted 401th balanced voxel
# Predicted 402th balanced voxel
# Predicted 403th balanced voxel
# Predicted 404th balanced voxel
# Predicted 405th balanced voxel
# Predicted 406th balanced voxel
# Predicted 407th balanced voxel
# Predicted 408th balanced voxel
# Predicted 409th balanced voxel
# Predicted 410th balanced voxel
# Predicted 411th balanced voxel
# Predicted 412th balanced voxel
# Predicted 413th balanced voxel
# Predicted 414th balanced voxel
# Predicted 415th balanced voxel
# Predicted 416th balanced voxel
# Predicted 417th balanced voxel
# Predicted 418th balanced voxel
# Predicted 419th balanced voxel
# Predicted 420th balanced voxel
# Predicted 421th balanced voxel
# Predicted 422th balanced voxel
# Predicted 423th balanced voxel
# Predicted 424th balanced voxel
# Predicted 425th balanced voxel
# Predicted 426th balanced voxel
# Predicted 427th balanced voxel
# Predicted 428th balanced voxel
# Predicted 429th balanced voxel
# Predicted 430th balanced voxel
# Predicted 431th balanced voxel
# Predicted 432th balanced voxel
# Predicted 433th balanced voxel
# Predicted 434th balanced voxel
# Predicted 435th balanced voxel
# Predicted 436th balanced voxel
# Predicted 437th balanced voxel
# Predicted 438th balanced voxel
# Predicted 439th balanced voxel
# Predicted 440th balanced voxel
# Predicted 441th balanced voxel
# Predicted 442th balanced voxel
# Predicted 443th balanced voxel
# Predicted 444th balanced voxel
# Predicted 445th balanced voxel
# Predicted 446th balanced voxel
# Predicted 447th balanced voxel
# Predicted 448th balanced voxel
# Predicted 449th balanced voxel
# Predicted 450th balanced voxel
# Predicted 451th balanced voxel
# Predicted 452th balanced voxel
# Predicted 453th balanced voxel
# Predicted 454th balanced voxel
# Predicted 455th balanced voxel
# Predicted 456th balanced voxel
# Predicted 457th balanced voxel
# Predicted 458th balanced voxel
# Predicted 459th balanced voxel
# Predicted 460th balanced voxel
# Predicted 461th balanced voxel
# Predicted 462th balanced voxel
# Predicted 463th balanced voxel
# Predicted 464th balanced voxel
# Predicted 465th balanced voxel
# Predicted 466th balanced voxel
# Predicted 467th balanced voxel
# Predicted 468th balanced voxel
# Predicted 469th balanced voxel
# Predicted 470th balanced voxel
# Predicted 471th balanced voxel
# Predicted 472th balanced voxel
# Predicted 473th balanced voxel
# Predicted 474th balanced voxel
# Predicted 475th balanced voxel
# Predicted 476th balanced voxel
# Predicted 477th balanced voxel
# Predicted 478th balanced voxel
# Predicted 479th balanced voxel
# Predicted 480th balanced voxel
# Predicted 481th balanced voxel
# Predicted 482th balanced voxel
# Predicted 483th balanced voxel
# Predicted 484th balanced voxel
# Predicted 485th balanced voxel
# Predicted 486th balanced voxel
# Predicted 487th balanced voxel
# Predicted 488th balanced voxel
# Predicted 489th balanced voxel
# Predicted 490th balanced voxel
# Predicted 491th balanced voxel
# Predicted 492th balanced voxel
# Predicted 493th balanced voxel
# Predicted 494th balanced voxel
# Predicted 495th balanced voxel
# Predicted 496th balanced voxel
# Predicted 497th balanced voxel
# Predicted 498th balanced voxel
# Predicted 499th balanced voxel
# Predicted 500th balanced voxel
# Predicted 501th balanced voxel
# Predicted 502th balanced voxel
# Predicted 503th balanced voxel
# Predicted 504th balanced voxel
# Predicted 505th balanced voxel
# Predicted 506th balanced voxel
# Predicted 507th balanced voxel
# Predicted 508th balanced voxel
# Predicted 509th balanced voxel
# Predicted 510th balanced voxel
# Predicted 511th balanced voxel
# Predicted 512th balanced voxel
# Predicted 513th balanced voxel
# Predicted 514th balanced voxel
# Predicted 515th balanced voxel
# Predicted 516th balanced voxel
# Predicted 517th balanced voxel
# Predicted 518th balanced voxel
# Predicted 519th balanced voxel
# Predicted 520th balanced voxel
# Predicted 521th balanced voxel
# Predicted 522th balanced voxel
# Predicted 523th balanced voxel
# Predicted 524th balanced voxel
# Predicted 525th balanced voxel
# Predicted 526th balanced voxel
# Predicted 527th balanced voxel
# Predicted 528th balanced voxel
# Predicted 529th balanced voxel
# Predicted 530th balanced voxel
# Predicted 531th balanced voxel
# Predicted 532th balanced voxel
# Predicted 533th balanced voxel
# Predicted 534th balanced voxel
# Predicted 535th balanced voxel
# Predicted 536th balanced voxel
# Predicted 537th balanced voxel
# Predicted 538th balanced voxel
# Predicted 539th balanced voxel
# Predicted 540th balanced voxel
# Predicted 541th balanced voxel
# Predicted 542th balanced voxel
# Predicted 543th balanced voxel
# Predicted 544th balanced voxel
# Predicted 545th balanced voxel
# Predicted 546th balanced voxel
# Predicted 547th balanced voxel
# Predicted 548th balanced voxel
# Predicted 549th balanced voxel
# Predicted 550th balanced voxel
# Predicted 551th balanced voxel
# Predicted 552th balanced voxel
# Predicted 553th balanced voxel
# Predicted 554th balanced voxel
# Predicted 555th balanced voxel
# Predicted 556th balanced voxel
# Predicted 557th balanced voxel
# Predicted 558th balanced voxel
# Predicted 559th balanced voxel
# Predicted 560th balanced voxel
# Predicted 561th balanced voxel
# Predicted 562th balanced voxel
# Predicted 563th balanced voxel
# Predicted 564th balanced voxel
# Predicted 565th balanced voxel
# Predicted 566th balanced voxel
# Predicted 567th balanced voxel
# Predicted 568th balanced voxel
# Predicted 569th balanced voxel
# Predicted 570th balanced voxel
# Predicted 571th balanced voxel
# Predicted 572th balanced voxel
# Predicted 573th balanced voxel
# Predicted 574th balanced voxel
# Predicted 575th balanced voxel
# Predicted 576th balanced voxel
# Predicted 577th balanced voxel
# Predicted 578th balanced voxel
# Predicted 579th balanced voxel
# Predicted 580th balanced voxel
# Predicted 581th balanced voxel
# Predicted 582th balanced voxel
# Predicted 583th balanced voxel
# Predicted 584th balanced voxel
# Predicted 585th balanced voxel
# Predicted 586th balanced voxel
# Predicted 587th balanced voxel
# Predicted 588th balanced voxel
# Predicted 589th balanced voxel
# Predicted 590th balanced voxel
# Predicted 591th balanced voxel
# Predicted 592th balanced voxel
# Predicted 593th balanced voxel
# Predicted 594th balanced voxel
# Predicted 595th balanced voxel
# Predicted 596th balanced voxel
# Predicted 597th balanced voxel
# Predicted 598th balanced voxel
# Predicted 599th balanced voxel
# Predicted 600th balanced voxel
# Predicted 601th balanced voxel
# Predicted 602th balanced voxel
# Predicted 603th balanced voxel
# Predicted 604th balanced voxel
# Predicted 605th balanced voxel
# Predicted 606th balanced voxel
# Predicted 607th balanced voxel
# Predicted 608th balanced voxel
# Predicted 609th balanced voxel
# Predicted 610th balanced voxel
# Predicted 611th balanced voxel
# Predicted 612th balanced voxel
# Predicted 613th balanced voxel
# Predicted 614th balanced voxel
# Predicted 615th balanced voxel
# Predicted 616th balanced voxel
# Predicted 617th balanced voxel
# Predicted 618th balanced voxel
# Predicted 619th balanced voxel
# Predicted 620th balanced voxel
# Predicted 621th balanced voxel
# Predicted 622th balanced voxel
# Predicted 623th balanced voxel
# Predicted 624th balanced voxel
# Predicted 625th balanced voxel
# Predicted 626th balanced voxel
# Predicted 627th balanced voxel
# Predicted 628th balanced voxel
# Predicted 629th balanced voxel
# Predicted 630th balanced voxel
# Predicted 631th balanced voxel
# Predicted 632th balanced voxel
# Predicted 633th balanced voxel
# Predicted 634th balanced voxel
# Predicted 635th balanced voxel
# Predicted 636th balanced voxel
# Predicted 637th balanced voxel
# Predicted 638th balanced voxel
# Predicted 639th balanced voxel
# Predicted 640th balanced voxel
# Predicted 641th balanced voxel
# Predicted 642th balanced voxel
# Predicted 643th balanced voxel
# Predicted 644th balanced voxel
# Predicted 645th balanced voxel
# Predicted 646th balanced voxel
# Predicted 647th balanced voxel
# Predicted 648th balanced voxel
# Predicted 649th balanced voxel
# Predicted 650th balanced voxel
# Predicted 651th balanced voxel
# Predicted 652th balanced voxel
# Predicted 653th balanced voxel
# Predicted 654th balanced voxel
# Predicted 655th balanced voxel
# Predicted 656th balanced voxel
# Predicted 657th balanced voxel
# Predicted 658th balanced voxel
# Predicted 659th balanced voxel
# Predicted 660th balanced voxel
# Predicted 661th balanced voxel
# Predicted 662th balanced voxel
# Predicted 663th balanced voxel
# Predicted 664th balanced voxel
# Predicted 665th balanced voxel
# Predicted 666th balanced voxel
# Predicted 667th balanced voxel
# Predicted 668th balanced voxel
# Predicted 669th balanced voxel
# Predicted 670th balanced voxel
# Predicted 671th balanced voxel
# Predicted 672th balanced voxel
# Predicted 673th balanced voxel
# Predicted 674th balanced voxel
# Predicted 675th balanced voxel
# Predicted 676th balanced voxel
# Predicted 677th balanced voxel
# Predicted 678th balanced voxel
# Predicted 679th balanced voxel
# Predicted 680th balanced voxel
# Predicted 681th balanced voxel
# Predicted 682th balanced voxel
# Predicted 683th balanced voxel
# Predicted 684th balanced voxel
# Predicted 685th balanced voxel
# Predicted 686th balanced voxel
# Predicted 687th balanced voxel
# Predicted 688th balanced voxel
# Predicted 689th balanced voxel
# Predicted 690th balanced voxel
# Predicted 691th balanced voxel
# Predicted 692th balanced voxel
# Predicted 693th balanced voxel
# Predicted 694th balanced voxel
# Predicted 695th balanced voxel
# Predicted 696th balanced voxel
# Predicted 697th balanced voxel
# Predicted 698th balanced voxel
# Predicted 699th balanced voxel
# Predicted 700th balanced voxel
# Predicted 701th balanced voxel
# Predicted 702th balanced voxel
# Predicted 703th balanced voxel
# Predicted 704th balanced voxel
# Predicted 705th balanced voxel
# Predicted 706th balanced voxel
# Predicted 707th balanced voxel
# Predicted 708th balanced voxel
# Predicted 709th balanced voxel
# Predicted 710th balanced voxel
# Predicted 711th balanced voxel
# Predicted 712th balanced voxel
# Predicted 713th balanced voxel
# Predicted 714th balanced voxel
# Predicted 715th balanced voxel
# Predicted 716th balanced voxel
# Predicted 717th balanced voxel
# Predicted 718th balanced voxel
# Predicted 719th balanced voxel
# Predicted 720th balanced voxel
# Predicted 721th balanced voxel
# Predicted 722th balanced voxel
# Predicted 723th balanced voxel
# Predicted 724th balanced voxel
# Predicted 725th balanced voxel
# Predicted 726th balanced voxel
# Predicted 727th balanced voxel
# Predicted 728th balanced voxel
# Predicted 729th balanced voxel
# Predicted 730th balanced voxel
# Predicted 731th balanced voxel
# Predicted 732th balanced voxel
# Predicted 733th balanced voxel
# Predicted 734th balanced voxel
# Predicted 735th balanced voxel
# Predicted 736th balanced voxel
# Predicted 737th balanced voxel
# Predicted 738th balanced voxel
# Predicted 739th balanced voxel
# Predicted 740th balanced voxel
# Predicted 741th balanced voxel
# Predicted 742th balanced voxel
# Predicted 743th balanced voxel
# Predicted 744th balanced voxel
# Predicted 745th balanced voxel
# Predicted 746th balanced voxel
# Predicted 747th balanced voxel
# Predicted 748th balanced voxel
# Predicted 749th balanced voxel
# Predicted 750th balanced voxel
# Predicted 751th balanced voxel
# Predicted 752th balanced voxel
# Predicted 753th balanced voxel
# Predicted 754th balanced voxel
# Predicted 755th balanced voxel
# Predicted 756th balanced voxel
# Predicted 757th balanced voxel
# Predicted 758th balanced voxel
# Predicted 759th balanced voxel
# Predicted 760th balanced voxel
# Predicted 761th balanced voxel
# Predicted 762th balanced voxel
# Predicted 763th balanced voxel
# Predicted 764th balanced voxel
# Predicted 765th balanced voxel
# Predicted 766th balanced voxel
# Predicted 767th balanced voxel
# Predicted 768th balanced voxel
# Predicted 769th balanced voxel
# Predicted 770th balanced voxel
# Predicted 771th balanced voxel
# Predicted 772th balanced voxel
# Predicted 773th balanced voxel
# Predicted 774th balanced voxel
# Predicted 775th balanced voxel
# Predicted 776th balanced voxel
# Predicted 777th balanced voxel
# Predicted 778th balanced voxel
# Predicted 779th balanced voxel
# Predicted 780th balanced voxel
# Predicted 781th balanced voxel
# Predicted 782th balanced voxel
# Predicted 783th balanced voxel
# Predicted 784th balanced voxel
# Predicted 785th balanced voxel
# Predicted 786th balanced voxel
# Predicted 787th balanced voxel
# Predicted 788th balanced voxel
# Predicted 789th balanced voxel
# Predicted 790th balanced voxel
# Predicted 791th balanced voxel
# Predicted 792th balanced voxel
# Predicted 793th balanced voxel
# Predicted 794th balanced voxel
# Predicted 795th balanced voxel
# Predicted 796th balanced voxel
# Predicted 797th balanced voxel
# Predicted 798th balanced voxel
# Predicted 799th balanced voxel
# Predicted 800th balanced voxel
# Predicted 801th balanced voxel
# Predicted 802th balanced voxel
# Predicted 803th balanced voxel
# Predicted 804th balanced voxel
# Predicted 805th balanced voxel
# Predicted 806th balanced voxel
# Predicted 807th balanced voxel
# Predicted 808th balanced voxel
# Predicted 809th balanced voxel
# Predicted 810th balanced voxel
# Predicted 811th balanced voxel
# Predicted 812th balanced voxel
# Predicted 813th balanced voxel
# Predicted 814th balanced voxel
# Predicted 815th balanced voxel
# Predicted 816th balanced voxel
# Predicted 817th balanced voxel
# Predicted 818th balanced voxel
# Predicted 819th balanced voxel
# Predicted 820th balanced voxel
# Predicted 821th balanced voxel
# Predicted 822th balanced voxel
# Predicted 823th balanced voxel
# Predicted 824th balanced voxel
# Predicted 825th balanced voxel
# Predicted 826th balanced voxel
# Predicted 827th balanced voxel
# Predicted 828th balanced voxel
# Predicted 829th balanced voxel
# Predicted 830th balanced voxel
# Predicted 831th balanced voxel
# Predicted 832th balanced voxel
# Predicted 833th balanced voxel
# Predicted 834th balanced voxel
# Predicted 835th balanced voxel
# Predicted 836th balanced voxel
# Predicted 837th balanced voxel
# Predicted 838th balanced voxel
# Predicted 839th balanced voxel
# Predicted 840th balanced voxel
# Predicted 841th balanced voxel
# Predicted 842th balanced voxel
# Predicted 843th balanced voxel
# Predicted 844th balanced voxel
# Predicted 845th balanced voxel
# Predicted 846th balanced voxel
# Predicted 847th balanced voxel
# Predicted 848th balanced voxel
# Predicted 849th balanced voxel
# Predicted 850th balanced voxel
# Predicted 851th balanced voxel
# Predicted 852th balanced voxel
# Predicted 853th balanced voxel
# Predicted 854th balanced voxel
# Predicted 855th balanced voxel
# Predicted 856th balanced voxel
# Predicted 857th balanced voxel
# Predicted 858th balanced voxel
# Predicted 859th balanced voxel
# Predicted 860th balanced voxel
# Predicted 861th balanced voxel
# Predicted 862th balanced voxel
# Predicted 863th balanced voxel
# Predicted 864th balanced voxel
# Predicted 865th balanced voxel
# Predicted 866th balanced voxel
# Predicted 867th balanced voxel
# Predicted 868th balanced voxel
# Predicted 869th balanced voxel
# Predicted 870th balanced voxel
# Predicted 871th balanced voxel
# Predicted 872th balanced voxel
# Predicted 873th balanced voxel
# Predicted 874th balanced voxel
# Predicted 875th balanced voxel
# Predicted 876th balanced voxel
# Predicted 877th balanced voxel
# Predicted 878th balanced voxel
# Predicted 879th balanced voxel
# Predicted 880th balanced voxel
# Predicted 881th balanced voxel
# Predicted 882th balanced voxel
# Predicted 883th balanced voxel
# Predicted 884th balanced voxel
# Predicted 885th balanced voxel
# Predicted 886th balanced voxel
# Predicted 887th balanced voxel
# Predicted 888th balanced voxel
# Predicted 889th balanced voxel
# Predicted 890th balanced voxel
# Predicted 891th balanced voxel
# Predicted 892th balanced voxel
# Predicted 893th balanced voxel
# Predicted 894th balanced voxel
# Predicted 895th balanced voxel
# Predicted 896th balanced voxel
# Predicted 897th balanced voxel
# Predicted 898th balanced voxel
# Predicted 899th balanced voxel
# Predicted 900th balanced voxel
# Predicted 901th balanced voxel
# Predicted 902th balanced voxel
# Predicted 903th balanced voxel
# Predicted 904th balanced voxel
# Predicted 905th balanced voxel
# Predicted 906th balanced voxel
# Predicted 907th balanced voxel
# Predicted 908th balanced voxel
# Predicted 909th balanced voxel
# Predicted 910th balanced voxel
# Predicted 911th balanced voxel
# Predicted 912th balanced voxel
# Predicted 913th balanced voxel
# Predicted 914th balanced voxel
# Predicted 915th balanced voxel
# Predicted 916th balanced voxel
# Predicted 917th balanced voxel
# Predicted 918th balanced voxel
# Predicted 919th balanced voxel
# Predicted 920th balanced voxel
# Predicted 921th balanced voxel
# Predicted 922th balanced voxel
# Predicted 923th balanced voxel
# Predicted 924th balanced voxel
# Predicted 925th balanced voxel
# Predicted 926th balanced voxel
# Predicted 927th balanced voxel
# Predicted 928th balanced voxel
# Predicted 929th balanced voxel
# Predicted 930th balanced voxel
# Predicted 931th balanced voxel
# Predicted 932th balanced voxel
# Predicted 933th balanced voxel
# Predicted 934th balanced voxel
# Inference complete. Voxels saved to output_voxel.npy, partial_voxel.npy, complete_voxel.npy.
# test.npy saved: all sampled truly empty voxels set to filled.

# %%
def inference_balanced_missing_empty_compact(model_path, test_samples, device):
    """
    Perform inference on a balanced set of voxels:
    - Half are missing voxels (present in complete, missing in partial)
    - Half are truly empty voxels (empty in both complete and partial), sampled to be close to the object (high filled neighbor density)
    Voxels are sorted by filled neighbor density using a generic cubic window of size `window_size` (must be odd),
    breaking ties by distance to origin.
    Additionally, save an npy file ('test.npy') where all sampled truly empty voxels are set to filled (1).
    """
    print(f"Using device: {device}")
    sample_idx = random.randint(0, len(test_samples)-1)
    sample_idx = 438
    complete, partial = test_samples[sample_idx]
    print(f"Selected sample index: {sample_idx}")

    # You can tweak these (kept small here)
    model = IterativeVoxelModel(
        d_model=48,
        num_heads=4,
        num_layers=3,
        max_grid_size=16,
        window_size=5,  # <-- generic window size; must be an odd integer
        dropout=0.1
    ).to(device)

    checkpoint = torch.load(model_path, map_location=device)
    state_dict = checkpoint['model_state_dict']
    from collections import OrderedDict
    new_state_dict = OrderedDict()
    for k, v in state_dict.items():
        new_key = k.replace('module.', '') if k.startswith('module.') else k
        new_state_dict[new_key] = v
    model.load_state_dict(new_state_dict)
    model.eval()

    partial_tensor = partial.unsqueeze(0).unsqueeze(0).to(device)  # [1,1,D,H,W]
    known_mask = (partial_tensor > 0).float()
    complete_tensor = complete.unsqueeze(0).unsqueeze(0).to(device)

    D, H, W = partial.shape
    window = int(model.window_size)
    assert window % 2 == 1 and window >= 1, "window_size must be an odd positive integer"

    # ---- Helper: generic neighbor counter for any odd window size ----
    def count_filled_neighbors(x, y, z, grid, win):
        """
        Count filled neighbors in a win x win x win cube centered at (x,y,z), excluding the center voxel.
        Assumes grid shape [1,1,D,H,W] with >0 treated as filled.
        """
        r = win // 2
        count = 0
        # clamp bounds once to avoid repeated checks
        x0, x1 = max(0, x - r), min(D - 1, x + r)
        y0, y1 = max(0, y - r), min(H - 1, y + r)
        z0, z1 = max(0, z - r), min(W - 1, z + r)
        for nx in range(x0, x1 + 1):
            for ny in range(y0, y1 + 1):
                for nz in range(z0, z1 + 1):
                    if nx == x and ny == y and nz == z:
                        continue  # exclude center
                    # grid is float/byte; >0 => filled
                    if grid[0, 0, nx, ny, nz] > 0:
                        count += 1
        return count

    # Find missing voxels: present in complete, missing in partial
    missing_voxels = torch.nonzero(
        (partial_tensor[0, 0] == 0) & (complete_tensor[0, 0] == 1),
        as_tuple=False
    ).to(device)  # [N,3]
    num_missing = missing_voxels.shape[0]

    # Find truly empty voxels: empty in both complete and partial
    truly_empty_voxels = torch.nonzero(
        (partial_tensor[0, 0] == 0) & (complete_tensor[0, 0] == 0),
        as_tuple=False
    ).to(device)  # [M,3]

    # --- Score truly empty voxels by density (generic window) and distance ---
    empty_scores = []
    for v in truly_empty_voxels:
        x, y, z = v.tolist()
        density = count_filled_neighbors(x, y, z, partial_tensor, window)
        dist = x**2 + y**2 + z**2
        empty_scores.append((x, y, z, density, dist))

    # Sort by high density, then close to origin
    empty_scores.sort(key=lambda t: (-t[3], t[4]))

    # Take top num_missing * FACTOR voxels
    FACTOR = 5
    limit = num_missing * FACTOR if num_missing > 0 else 0
    sampled_empty_voxels = (
        torch.tensor([s[:3] for s in empty_scores[:limit]], dtype=torch.long, device=device)
        if limit > 0 and len(empty_scores) > 0 else
        torch.empty((0, 3), dtype=torch.long, device=device)
    )

    # Candidate voxels: union of missing + sampled empties
    candidate_voxels = (
        torch.cat([missing_voxels, sampled_empty_voxels], dim=0)
        if missing_voxels.numel() > 0 or sampled_empty_voxels.numel() > 0
        else torch.empty((0, 3), dtype=torch.long, device=device)
    )

    # Sort candidates by density (generic window) and distance to origin
    voxel_scores = []
    for v in candidate_voxels:
        x, y, z = v.tolist()
        density = count_filled_neighbors(x, y, z, partial_tensor, window)
        dist = x**2 + y**2 + z**2
        voxel_scores.append((x, y, z, density, dist))
    voxel_scores.sort(key=lambda t: (-t[3], t[4]))
    sorted_voxels = [(x, y, z) for x, y, z, _, _ in voxel_scores]

    print(f"Entering prediction for {len(sorted_voxels)} balanced voxels...")
    with torch.no_grad():
        for i, (x, y, z) in enumerate(sorted_voxels):
            patch, mask_patch = neighborhood_raw(partial_tensor, 0, x, y, z, window)
            logits = model(patch.to(device), mask_patch.to(device))
            prob = torch.sigmoid(logits).squeeze().item()
            pred_filled = 1.0 if prob > 0.5 else 0.0
            partial_tensor[0, 0, x, y, z] = pred_filled
            known_mask[0, 0, x, y, z] = 1.0
            print(f"Predicted {i}th balanced voxel")
            if i %50 == 0:
                np.save(f"output_voxel_{i}.npy", partial_tensor.squeeze().cpu().numpy())

    output_voxels = partial_tensor.squeeze().cpu().numpy()
    np.save("output_voxel.npy", output_voxels)
    np.save("partial_voxel.npy", partial.numpy())
    np.save("complete_voxel.npy", complete.numpy())
    print("Inference complete. Voxels saved to output_voxel.npy, partial_voxel.npy, complete_voxel.npy.")

    # --- Save test.npy with all sampled truly empty voxels set to filled (1) ---
    test_voxel = partial.clone()
    for v in sampled_empty_voxels:
        x, y, z = v.tolist()
        test_voxel[x, y, z] = 1.0
    np.save("test.npy", test_voxel.cpu().numpy())
    print("test.npy saved: all sampled truly empty voxels set to filled.")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
inference_balanced_missing_empty_compact(MODEL_SAVE_PATH, test_samples, device=device)
# Out:
# Using device: cuda
# Selected sample index: 438
# Entering prediction for 216 balanced voxels...
# Predicted 0th balanced voxel
# Predicted 1th balanced voxel
# Predicted 2th balanced voxel
# Predicted 3th balanced voxel
# Predicted 4th balanced voxel
# Predicted 5th balanced voxel
# Predicted 6th balanced voxel
# Predicted 7th balanced voxel
# Predicted 8th balanced voxel
# Predicted 9th balanced voxel
# Predicted 10th balanced voxel
# Predicted 11th balanced voxel
# Predicted 12th balanced voxel
# Predicted 13th balanced voxel
# Predicted 14th balanced voxel
# Predicted 15th balanced voxel
# Predicted 16th balanced voxel
# Predicted 17th balanced voxel
# Predicted 18th balanced voxel
# Predicted 19th balanced voxel
# Predicted 20th balanced voxel
# Predicted 21th balanced voxel
# Predicted 22th balanced voxel
# Predicted 23th balanced voxel
# Predicted 24th balanced voxel
# Predicted 25th balanced voxel
# Predicted 26th balanced voxel
# Predicted 27th balanced voxel
# Predicted 28th balanced voxel
# Predicted 29th balanced voxel
# Predicted 30th balanced voxel
# Predicted 31th balanced voxel
# Predicted 32th balanced voxel
# Predicted 33th balanced voxel
# Predicted 34th balanced voxel
# Predicted 35th balanced voxel
# Predicted 36th balanced voxel
# Predicted 37th balanced voxel
# Predicted 38th balanced voxel
# Predicted 39th balanced voxel
# Predicted 40th balanced voxel
# Predicted 41th balanced voxel
# Predicted 42th balanced voxel
# Predicted 43th balanced voxel
# Predicted 44th balanced voxel
# Predicted 45th balanced voxel
# Predicted 46th balanced voxel
# Predicted 47th balanced voxel
# Predicted 48th balanced voxel
# Predicted 49th balanced voxel
# Predicted 50th balanced voxel
# Predicted 51th balanced voxel
# Predicted 52th balanced voxel
# Predicted 53th balanced voxel
# Predicted 54th balanced voxel
# Predicted 55th balanced voxel
# Predicted 56th balanced voxel
# Predicted 57th balanced voxel
# Predicted 58th balanced voxel
# Predicted 59th balanced voxel
# Predicted 60th balanced voxel
# Predicted 61th balanced voxel
# Predicted 62th balanced voxel
# Predicted 63th balanced voxel
# Predicted 64th balanced voxel
# Predicted 65th balanced voxel
# Predicted 66th balanced voxel
# Predicted 67th balanced voxel
# Predicted 68th balanced voxel
# Predicted 69th balanced voxel
# Predicted 70th balanced voxel
# Predicted 71th balanced voxel
# Predicted 72th balanced voxel
# Predicted 73th balanced voxel
# Predicted 74th balanced voxel
# Predicted 75th balanced voxel
# Predicted 76th balanced voxel
# Predicted 77th balanced voxel
# Predicted 78th balanced voxel
# Predicted 79th balanced voxel
# Predicted 80th balanced voxel
# Predicted 81th balanced voxel
# Predicted 82th balanced voxel
# Predicted 83th balanced voxel
# Predicted 84th balanced voxel
# Predicted 85th balanced voxel
# Predicted 86th balanced voxel
# Predicted 87th balanced voxel
# Predicted 88th balanced voxel
# Predicted 89th balanced voxel
# Predicted 90th balanced voxel
# Predicted 91th balanced voxel
# Predicted 92th balanced voxel
# Predicted 93th balanced voxel
# Predicted 94th balanced voxel
# Predicted 95th balanced voxel
# Predicted 96th balanced voxel
# Predicted 97th balanced voxel
# Predicted 98th balanced voxel
# Predicted 99th balanced voxel
# Predicted 100th balanced voxel
# Predicted 101th balanced voxel
# Predicted 102th balanced voxel
# Predicted 103th balanced voxel
# Predicted 104th balanced voxel
# Predicted 105th balanced voxel
# Predicted 106th balanced voxel
# Predicted 107th balanced voxel
# Predicted 108th balanced voxel
# Predicted 109th balanced voxel
# Predicted 110th balanced voxel
# Predicted 111th balanced voxel
# Predicted 112th balanced voxel
# Predicted 113th balanced voxel
# Predicted 114th balanced voxel
# Predicted 115th balanced voxel
# Predicted 116th balanced voxel
# Predicted 117th balanced voxel
# Predicted 118th balanced voxel
# Predicted 119th balanced voxel
# Predicted 120th balanced voxel
# Predicted 121th balanced voxel
# Predicted 122th balanced voxel
# Predicted 123th balanced voxel
# Predicted 124th balanced voxel
# Predicted 125th balanced voxel
# Predicted 126th balanced voxel
# Predicted 127th balanced voxel
# Predicted 128th balanced voxel
# Predicted 129th balanced voxel
# Predicted 130th balanced voxel
# Predicted 131th balanced voxel
# Predicted 132th balanced voxel
# Predicted 133th balanced voxel
# Predicted 134th balanced voxel
# Predicted 135th balanced voxel
# Predicted 136th balanced voxel
# Predicted 137th balanced voxel
# Predicted 138th balanced voxel
# Predicted 139th balanced voxel
# Predicted 140th balanced voxel
# Predicted 141th balanced voxel
# Predicted 142th balanced voxel
# Predicted 143th balanced voxel
# Predicted 144th balanced voxel
# Predicted 145th balanced voxel
# Predicted 146th balanced voxel
# Predicted 147th balanced voxel
# Predicted 148th balanced voxel
# Predicted 149th balanced voxel
# Predicted 150th balanced voxel
# Predicted 151th balanced voxel
# Predicted 152th balanced voxel
# Predicted 153th balanced voxel
# Predicted 154th balanced voxel
# Predicted 155th balanced voxel
# Predicted 156th balanced voxel
# Predicted 157th balanced voxel
# Predicted 158th balanced voxel
# Predicted 159th balanced voxel
# Predicted 160th balanced voxel
# Predicted 161th balanced voxel
# Predicted 162th balanced voxel
# Predicted 163th balanced voxel
# Predicted 164th balanced voxel
# Predicted 165th balanced voxel
# Predicted 166th balanced voxel
# Predicted 167th balanced voxel
# Predicted 168th balanced voxel
# Predicted 169th balanced voxel
# Predicted 170th balanced voxel
# Predicted 171th balanced voxel
# Predicted 172th balanced voxel
# Predicted 173th balanced voxel
# Predicted 174th balanced voxel
# Predicted 175th balanced voxel
# Predicted 176th balanced voxel
# Predicted 177th balanced voxel
# Predicted 178th balanced voxel
# Predicted 179th balanced voxel
# Predicted 180th balanced voxel
# Predicted 181th balanced voxel
# Predicted 182th balanced voxel
# Predicted 183th balanced voxel
# Predicted 184th balanced voxel
# Predicted 185th balanced voxel
# Predicted 186th balanced voxel
# Predicted 187th balanced voxel
# Predicted 188th balanced voxel
# Predicted 189th balanced voxel
# Predicted 190th balanced voxel
# Predicted 191th balanced voxel
# Predicted 192th balanced voxel
# Predicted 193th balanced voxel
# Predicted 194th balanced voxel
# Predicted 195th balanced voxel
# Predicted 196th balanced voxel
# Predicted 197th balanced voxel
# Predicted 198th balanced voxel
# Predicted 199th balanced voxel
# Predicted 200th balanced voxel
# Predicted 201th balanced voxel
# Predicted 202th balanced voxel
# Predicted 203th balanced voxel
# Predicted 204th balanced voxel
# Predicted 205th balanced voxel
# Predicted 206th balanced voxel
# Predicted 207th balanced voxel
# Predicted 208th balanced voxel
# Predicted 209th balanced voxel
# Predicted 210th balanced voxel
# Predicted 211th balanced voxel
# Predicted 212th balanced voxel
# Predicted 213th balanced voxel
# Predicted 214th balanced voxel
# Predicted 215th balanced voxel
# Inference complete. Voxels saved to output_voxel.npy, partial_voxel.npy, complete_voxel.npy.
# test.npy saved: all sampled truly empty voxels set to filled.

# %%
import math

def iterative_inference(model_path, test_samples, device, no_change_patience=100, prob_threshold=0.9):
    """
    Perform iterative inference on a random partial voxel object from test_samples.
    Sorts empty voxels by density in a window (model.window_size), breaking ties by distance to origin.
    Stops early if there are `no_change_patience` consecutive voxels with no change.
    """
    print(f"Using device: {device}")
    sample_idx = random.randint(0, len(test_samples)-1)
    # sample_idx = 300
    complete, partial = test_samples[sample_idx]
    print(f"Selected sample index: {sample_idx}")

    model = IterativeVoxelModel(
        d_model=48,
        num_heads=4,
        num_layers=3,
        max_grid_size=16,
        window_size=5,   # uses generic neighbor window you added earlier
        dropout=0.1
    ).to(device)

    checkpoint = torch.load(model_path, map_location=device)
    state_dict = checkpoint['model_state_dict']
    from collections import OrderedDict
    new_state_dict = OrderedDict()
    for k, v in state_dict.items():
        new_key = k.replace('module.', '') if k.startswith('module.') else k
        new_state_dict[new_key] = v
    model.load_state_dict(new_state_dict)
    model.eval()

    partial_tensor = partial.unsqueeze(0).unsqueeze(0).to(device)  # [1,1,D,H,W]
    known_mask = (partial_tensor > 0).float()

    D, H, W = partial.shape
    window = int(model.window_size)

    # --- neighbor density (generic window) ---
    def count_filled_neighbors(x, y, z, grid, win):
        r = win // 2
        x0, x1 = max(0, x - r), min(D - 1, x + r)
        y0, y1 = max(0, y - r), min(H - 1, y + r)
        z0, z1 = max(0, z - r), min(W - 1, z + r)
        cnt = 0
        for nx in range(x0, x1 + 1):
            for ny in range(y0, y1 + 1):
                for nz in range(z0, z1 + 1):
                    if nx == x and ny == y and nz == z:
                        continue
                    if grid[0, 0, nx, ny, nz] > 0:
                        cnt += 1
        return cnt

    empty_voxels = torch.nonzero(partial_tensor[0, 0] == 0, as_tuple=False)  # [N,3]
    voxel_scores = []
    for v in empty_voxels:
        x, y, z = v.tolist()
        density = count_filled_neighbors(x, y, z, partial_tensor, window)
        dist = x**2 + y**2 + z**2
        voxel_scores.append((x, y, z, density, dist))
    voxel_scores.sort(key=lambda t: (-t[3], t[4]))
    sorted_empty_voxels = [(x, y, z) for x, y, z, _, _ in voxel_scores]

    # --- early-stop state ---
    no_change_run = 0

    print("Entering prediction...")
    with torch.inference_mode():  # slightly faster than no_grad
        for i, (x, y, z) in enumerate(sorted_empty_voxels):
            old_val = partial_tensor[0, 0, x, y, z]  # tensor scalar on device

            patch, mask_patch = neighborhood_raw(partial_tensor, 0, x, y, z, window)
            logits = model(patch.to(device), mask_patch.to(device))
            prob = torch.sigmoid(logits).squeeze().item()
            pred_filled = 1.0 if prob > prob_threshold else 0.0
            partial_tensor[0, 0, x, y, z] = pred_filled
            changed = (pred_filled != old_val).item()
            known_mask[0, 0, x, y, z] = 1.0

            if changed:
                no_change_run = 0
            else:
                no_change_run += 1
                if no_change_run >= no_change_patience:
                    print(f"No change for {no_change_patience} consecutive voxels. Early stopping at i={i}.")
                    break

            if (i % 500) == 0:
                print(f"Predicted {i}/{len(sorted_empty_voxels)} (no-change run={no_change_run})")

    # Save outputs
    output_voxels = partial_tensor.squeeze().cpu().numpy()
    np.save("output_voxel.npy", output_voxels)
    np.save("partial_voxel.npy", partial.numpy())
    np.save("complete_voxel.npy", complete.numpy())
    print("Inference complete. Voxels saved to output_voxel.npy, partial_voxel.npy, complete_voxel.npy.")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
iterative_inference(MODEL_SAVE_PATH, test_samples, device=device, no_change_patience=1000, prob_threshold=0.9)
# interesting 641
# 300
# Out:
# Using device: cuda
# Selected sample index: 292
# Entering prediction...
# Predicted 0/3842 (no-change run=1)
# Predicted 500/3842 (no-change run=501)
# No change for 1000 consecutive voxels. Early stopping at i=999.
# Inference complete. Voxels saved to output_voxel.npy, partial_voxel.npy, complete_voxel.npy.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
iterative_inference("iterative_model_ws_5.pth", test_samples, device=device, no_change_patience=1000, prob_threshold=0.9)
# Out:
# Using device: cuda
# Selected sample index: 300
# Entering prediction...
# Predicted 0/3546 (no-change run=1)
# Predicted 500/3546 (no-change run=501)
# No change for 1000 consecutive voxels. Early stopping at i=999.
# Inference complete. Voxels saved to output_voxel.npy, partial_voxel.npy, complete_voxel.npy.
